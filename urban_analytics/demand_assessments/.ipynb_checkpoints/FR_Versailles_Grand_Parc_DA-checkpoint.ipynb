# %% [markdown]
# # Versailles Demand Assessment
# ### Setup

# %%
from urban_analytics.utils import *
from urban_analytics.imports import *
from urban_analytics.geography import *
from urban_analytics.fleet_sizing import *
from urban_analytics.h3_utils import *
from urban_analytics.osm import *
from urban_analytics.scoring import *
from urban_analytics.population import *
from urban_analytics.station_selection import *
from urban_analytics.maps import *

from matplotlib.lines import Line2D
import contextily as cx
# from matplotlib.legend_handler import HandlerLine2D
# from matplotlib.patches import Patch
# import fiona

# %%
place = 'Versailles'
country_code = 'FR'

local_crs = LocalCRS[country_code].value
data_dir_in, data_dir_out = set_up_directories(country_code, place)
# Out:
# data_dir_in already exists
# data_dir_out already exists

# %% [markdown]
# ## City selection

# %% [markdown]
# <font color='#8db0f0'><b>France</b></font>

# %%
target_cities_df = get_city_selection_df(
    target_city_name=[place], 
    # city_subset=
)

target_cities_df
# Out:
# 18 cities found
# 1 area(s) (CA Versailles Grand Parc (C.A.V.G.P.))
#                      city_name                              area_name  \
# 30503                   Bailly  CA Versailles Grand Parc (C.A.V.G.P.)
# 30514              Bois-d'Arcy  CA Versailles Grand Parc (C.A.V.G.P.)
# 30522                 Bougival  CA Versailles Grand Parc (C.A.V.G.P.)
# 30528                      Buc  CA Versailles Grand Parc (C.A.V.G.P.)
# 30534     La Celle-Saint-Cloud  CA Versailles Grand Parc (C.A.V.G.P.)
# 30539              Châteaufort  CA Versailles Grand Parc (C.A.V.G.P.)
# 30543  Le Chesnay-Rocquencourt  CA Versailles Grand Parc (C.A.V.G.P.)
# 30576       Fontenay-le-Fleury  CA Versailles Grand Parc (C.A.V.G.P.)
# 30608            Jouy-en-Josas  CA Versailles Grand Parc (C.A.V.G.P.)
# 30616       Les Loges-en-Josas  CA Versailles Grand Parc (C.A.V.G.P.)
# 30664             Noisy-le-Roi  CA Versailles Grand Parc (C.A.V.G.P.)
# 30688              Rennemoulin  CA Versailles Grand Parc (C.A.V.G.P.)
# 30696        Saint-Cyr-l'École  CA Versailles Grand Parc (C.A.V.G.P.)
# 30725         Toussus-le-Noble  CA Versailles Grand Parc (C.A.V.G.P.)
# 30730      Vélizy-Villacoublay  CA Versailles Grand Parc (C.A.V.G.P.)
# 30734               Versailles  CA Versailles Grand Parc (C.A.V.G.P.)
# 30745                 Viroflay  CA Versailles Grand Parc (C.A.V.G.P.)
# 34351                  Bièvres  CA Versailles Grand Parc (C.A.V.G.P.)
#
#       dept_name dept_id    region_name  region_id
# 30503  YVELINES      78  ILE DE FRANCE         11
# 30514  YVELINES      78  ILE DE FRANCE         11
# 30522  YVELINES      78  ILE DE FRANCE         11
# 30528  YVELINES      78  ILE DE FRANCE         11
# 30534  YVELINES      78  ILE DE FRANCE         11
# 30539  YVELINES      78  ILE DE FRANCE         11
# 30543  YVELINES      78  ILE DE FRANCE         11
# 30576  YVELINES      78  ILE DE FRANCE         11
# 30608  YVELINES      78  ILE DE FRANCE         11
# 30616  YVELINES      78  ILE DE FRANCE         11
# 30664  YVELINES      78  ILE DE FRANCE         11
# 30688  YVELINES      78  ILE DE FRANCE         11
# 30696  YVELINES      78  ILE DE FRANCE         11
# 30725  YVELINES      78  ILE DE FRANCE         11
# 30730  YVELINES      78  ILE DE FRANCE         11
# 30734  YVELINES      78  ILE DE FRANCE         11
# 30745  YVELINES      78  ILE DE FRANCE         11
# 34351   ESSONNE      91  ILE DE FRANCE         11

# %% [markdown]
# <font color='#8db0f0'><b>Rest of the world</b></font>

# %% [raw]
# target_city_name = place
#
# # # using our datasets
# fr_vls = load_fleet_info(vls=True)
# target_cities_df = fr_vls.query("country_id == @country_code and city in @place").copy()
#
# # target_cities_df.loc[:,'pop'] = 300_000
# target_cities_df.loc[:,'pop'] = 5_614_000
# target_cities_df.loc[:,'area_km2'] = 600
# target_cities_df
# # np.sort(fr_vls.query("country_id == @country_code").city.unique()).tolist()[:20]
#
# # using citypopulation.de
# # country_city_stats = get_country_city_stats(country_code)
# # city_info = country_city_stats.query("city in [@target_city_name]")
# # city_info = reset_city_typology(city_info)
# # city_info

# %% [markdown]
# ## Fleet sizing
# #### __Long-term rental scheme (VLD)__

# %% [markdown]
# <font color='#8db0f0'><b>France</b></font>

# %%
market_vld = get_vld_fleet(target_cities_df, batches=5)
print('Recommended long bike rental fleet size by city:')
print(f"{len(market_vld)} cities and {int(market_vld.bikes_lower.sum())}-{int(market_vld.bikes_upper.sum())} bikes")
print_fleet_df(market_vld[['city','bikes',]])
# Out:
# Recommended long bike rental fleet size by city:
# 18 cities and 75-1025 bikes
#                           city  bikes
# 1                   Versailles    225
# 2      Le Chesnay-Rocquencourt     90
# 3          Vélizy-Villacoublay     50
# 4                     Viroflay     40
# 5            Saint-Cyr-l'École     40
# 6         La Celle-Saint-Cloud     40
# 7                  Bois-d'Arcy     25
# 8           Fontenay-le-Fleury     25
# 9                Jouy-en-Josas     10
# 10                    Bougival     10
# 11                 Châteaufort      0
# 12                         Buc      0
# 13                 Rennemoulin      0
# 14                Noisy-le-Roi      0
# 15                      Bailly      0
# 16          Les Loges-en-Josas      0
# 17            Toussus-le-Noble      0
# 18                     Bièvres      0
# Total                             555

# %%
# Increasing fleet size
market_vld_2 = reset_fleet(market_vld, vld=True)
market_vld_2['bikes_max_2'] = my_round(market_vld_2['bikes_max_2'],10).astype(int)
print('VLD Market Sizing (increased)')
print_fleet_df(market_vld_2.rename(columns={'bikes_max_2':'Bikes'})[['city','Bikes']])
# Out:
# VLD Market Sizing (increased)
#                           city  Bikes
# 1                   Versailles    210
# 2      Le Chesnay-Rocquencourt     80
# 3          Vélizy-Villacoublay     50
# 4         La Celle-Saint-Cloud     50
# 5            Saint-Cyr-l'École     40
# 6                     Viroflay     40
# 7                  Bois-d'Arcy     40
# 8           Fontenay-le-Fleury     30
# 9                Jouy-en-Josas     20
# 10                    Bougival     20
# 11                Noisy-le-Roi     20
# 12                         Buc     10
# 13                     Bièvres     10
# 14                      Bailly     10
# 15          Les Loges-en-Josas      0
# 16                 Châteaufort      0
# 17            Toussus-le-Noble      0
# 18                 Rennemoulin      0
# Total                             630

# %% [raw]
# market_vld = market_vld_2

# %% [markdown]
# <font color='#8db0f0'><b>Rest of the world</b></font>

# %% [raw]
# city_info = target_cities_df[['city','pop','area_km2']].pipe(reset_city_typology)
# city_info

# %% [raw]
# # # manual population
# # new_market_vls = pd.DataFrame({'city':['Central Region','year_round'],
# #                                'pop':[30_600,17800],
# #                                'area_km2':[170,170]
# #                               })
#
# link = "https://en.wikipedia.org/wiki/Regions_of_Malta"
#
# tables = pd.read_html(link)
# city_info = tables[2][['Region','Area','Population (2014)']]
# city_info = (
#     city_info
#     .rename(columns={'Region':'city','Area':'area_km2','Population (2014)':'pop'})
#     .assign(area_km2=lambda x: x.area_km2.str.split('km2').str[0])
#     .astype({'area_km2':float,'pop':int,'city':str})
#     .pipe(reset_city_typology)
#     .sort_values('pop',ascending=False)
# )
# city_info

# %% [raw]
# fr_vld = load_fleet_info(vld=True)
#
# vld_stats = (
#     fr_vld
#     .groupby("typology")
#     .first()[["min_bikes_km2",
#               "avg_bikes_km2",
#               "max_bikes_km2",
#               "min_bikes_10000ppl",
#               "max_bikes_10000ppl",]]
#     )
#
# df = (
#     city_info
#     .merge(vld_stats, on="typology", how="left")
#     .assign(
#         bikes_min_1 = lambda x: (x.area_km2 * x.min_bikes_km2) / 3,
#         bikes_max_1 = lambda x: (x.area_km2 * x.max_bikes_km2) / 3,
#         bikes_min_2 = lambda x: (x["pop"] / 10_000) * x.min_bikes_10000ppl,
#         bikes_max_2 = lambda x: (x["pop"] / 10_000) * x.max_bikes_10000ppl,
#         bikes_min = lambda x: x[["bikes_min_1", "bikes_min_2"]].mean(axis=1).astype(int),
#         bikes_max = lambda x: x[["bikes_max_1", "bikes_max_2"]].mean(axis=1).astype(int),
#         bikes = lambda x: myround(x[["bikes_min", "bikes_max"]].mean(axis=1)).astype(int),
#     )
# )
#
#
#
# market_vld=df.sort_values("pop", ascending=False)
# print_fleet_df(market_vld[['city','bikes','bikes_max']])

# %% [markdown]
# #### __Bikeshare (VLS)__

# %% [markdown]
# <font color='#8db0f0'><b>France</b></font>

# %%
market_vls = get_vls_fleet(target_cities_df, batches=10)
print('VLS Market Sizing')
print_fleet_df(market_vls[['city','bikes','bikes_min','bikes_max','stations']])
# Out:
# VLS Market Sizing
#                           city  bikes  bikes_min  bikes_max  stations
# 1                   Versailles    250         76        423        45
# 2      Le Chesnay-Rocquencourt     50         28         80         9
# 3          Vélizy-Villacoublay     20         19         27         4
# 4                     Viroflay     20         14         19         4
# 5            Saint-Cyr-l'École     20         16         22         4
# 6                  Bois-d'Arcy     20         13         18         4
# 7         La Celle-Saint-Cloud     20         18         24         4
# 8                          Buc     10          5          7         2
# 9                Jouy-en-Josas     10          7         10         2
# 10          Fontenay-le-Fleury     10         11         16         2
# 11                Noisy-le-Roi     10          6          9         2
# 12                    Bougival     10          7         10         2
# 13                 Rennemoulin      0          0          0         0
# 14                 Châteaufort      0          1          1         0
# 15            Toussus-le-Noble      0          0          1         0
# 16          Les Loges-en-Josas      0          1          1         0
# 17                      Bailly      0          0          0         0
# 18                     Bièvres      0          4          5         0
# Total                             450        226        673        84

# %%
def reset_fleet(df: pd.DataFrame, vld: bool = False, vls: bool = False, batches= 10) -> pd.DataFrame:
    """
    Force reset vld or vls fleet size by updating city typology and recomputing fleet.

    Arguments:
        df: fleet df obtained from `get_vls_fleet` or `get_vld_fleet`
        vld: set to true if reseting vld fleet
        vls: set to true if reseting vls fleet
    """
    if vld == vls:
        raise ValueError("Select either vls or vld fleet type")
    fleet_df = load_fleet_info(vld=vld, vls=vls)

    stats_df = fleet_df.groupby("typology").first()[
        [
            "min_bikes_km2",
            "avg_bikes_km2",
            "max_bikes_km2",
            "min_bikes_10000ppl",
            "max_bikes_10000ppl",
        ]
    ]
    return (
        df.pipe(reset_city_typology)
        .merge(stats_df, on="typology", how="left")
        .assign(
            bikes_min_1=lambda x: (x.area_km2 * x.min_bikes_km2) / 3,
            bikes_max_1=lambda x: (x.area_km2 * x.max_bikes_km2) / 3,
            bikes_min_2=lambda x: (x["pop"] / 10_000) * x.min_bikes_10000ppl,
            bikes_max_2=lambda x: (x["pop"] / 10_000) * x.max_bikes_10000ppl,
            bikes_min=lambda x: my_round(x[["bikes_min_1", "bikes_min_2"]].min(axis=1), base=10),
            bikes_max=lambda x: my_round(x[["bikes_max_1", "bikes_max_2"]].max(axis=1), base=10),
            bikes_pop=lambda x: x[["bikes_min_2", "bikes_max_2"]].mean(axis=1),
            bikes=lambda x: x[["bikes_min", "bikes_max"]].mean(axis=1),
            stations=lambda x: compute_stations_given_bikes(x.bikes),
        )
        .astype(
            {
                "bikes_min": int,
                "bikes_max": int,
                "bikes_pop": int,
                "bikes": int,
                "stations": int,
            }
        )
        .sort_values("pop", ascending=False)
    )

# %%
market_vls_2 = reset_fleet(market_vls,vls=True)
print('VLS Market Sizing (increased)')
print_fleet_df(market_vls_2[['city','pop','bikes','bikes_min_2','bikes_max_2','stations']])
# Out:
# VLS Market Sizing (increased)
#                           city     pop  bikes  bikes_min_2  bikes_max_2  stations
# 1                   Versailles   69969    265      76.9659   506.278348        48
# 2      Le Chesnay-Rocquencourt   25904     70      28.4944   131.469028        13
# 3          Vélizy-Villacoublay   18098     25      19.9078    27.147000         4
# 4         La Celle-Saint-Cloud   16485     20      18.1335    24.727500         4
# 5            Saint-Cyr-l'École   14753     20      16.2283    22.129500         4
# 6                     Viroflay   12965     15      14.2615    19.447500         3
# 7                  Bois-d'Arcy   12115     15      13.3265    18.172500         3
# 8           Fontenay-le-Fleury   10906     15      11.9966    16.359000         3
# 9                Jouy-en-Josas    6967     25       7.6637    10.450500         4
# 10                    Bougival    6832     10       7.5152    10.248000         2
# 11                Noisy-le-Roi    6087     15       6.6957     9.130500         3
# 12                         Buc    4675     20       5.1425     7.012500         4
# 13                     Bièvres    3705     20       4.0755     5.557500         4
# 14          Les Loges-en-Josas    1208      5       1.3288     1.812000         1
# 15                 Châteaufort    1107     10       1.2177     1.660500         2
# 16            Toussus-le-Noble     867      5       0.9537     1.300500         1
# 17                      Bailly     523     10       0.5753     0.784500         2
# 18                 Rennemoulin      85      5       0.0935     0.127500         1
# Total                           213251    570     234.0000   813.000000       106

# %% [raw]
# market_vls = market_vls_2

# %% [markdown]
# <font color='#8db0f0'><b>Rest of the world</b></font>

# %% [raw]
# fr_vls = load_fleet_info(vls=True)
#
# vls_stats = (
#         # fr_vls.query("country_id == @country_code")
#         fr_vls.query("region == 'Europe'")
#         # fr_vls.query("country_id == 'FR'")
#         .groupby("typology")
#         .first()[["min_bikes_km2",
#                 "avg_bikes_km2",
#                 "max_bikes_km2",
#                 "min_bikes_10000ppl",
#                 "max_bikes_10000ppl",]]
#     )
#
# df = city_info.merge(vls_stats, on="typology", how="left")
# df["bikes_min_1"] = (df["area_km2"] * df["min_bikes_km2"]) / 4
# df["bikes_max_1"] = (df["area_km2"] * df["max_bikes_km2"]) / 4
#
# df["bikes_min_2"] = (df["pop"] / 10_000) * df["min_bikes_10000ppl"]
# df["bikes_max_2"] = (df["pop"] / 10_000) * df["max_bikes_10000ppl"]
#
# df["bikes_min"] = df[["bikes_min_1", "bikes_min_2"]].mean(axis=1)
# df["bikes_max"] = df[["bikes_max_1", "bikes_max_2"]].mean(axis=1)
# df = df.assign(
#     bikes=lambda x: myround(x[["bikes_min", "bikes_max"]].mean(axis=1)).astype(int)-20,
#     stations=lambda x: round(compute_stations_given_bikes(x.bikes)).astype(int),
# )
#
# market_vls=df.sort_values("pop", ascending=False)
# print_fleet_df(market_vls[['city','bikes','stations']])

# %% [markdown]
# ## Tweak fleet sizing

# %%
market_vls
# Out:
#                        city    pop   area_km2  bikes_min  bikes_max  bikes  \
# 0                Versailles  69969  25.650187         76        423    250
# 1   Le Chesnay-Rocquencourt  25904   7.155888         28         80     50
# 2       Vélizy-Villacoublay  18098   8.887469         19         27     20
# 3                  Viroflay  12965   3.591937         14         19     20
# 4         Saint-Cyr-l'École  14753   5.502141         16         22     20
# 5               Bois-d'Arcy  12115   5.560766         13         18     20
# 6      La Celle-Saint-Cloud  16485   5.873342         18         24     20
# 7                       Buc   4675   8.122182          5          7     10
# 8             Jouy-en-Josas   6967  10.849063          7         10     10
# 9        Fontenay-le-Fleury  10906   5.437200         11         16     10
# 10             Noisy-le-Roi   6087   5.831852          6          9     10
# 11                 Bougival   6832   2.629830          7         10     10
# 12              Rennemoulin     85   1.951771          0          0      0
# 13              Châteaufort   1107   5.033255          1          1      0
# 14         Toussus-le-Noble    867   3.843630          0          1      0
# 15       Les Loges-en-Josas   1208   2.122564          1          1      0
# 16                   Bailly    523   4.175328          0          0      0
# 17                  Bièvres   3705   9.930275          4          5      0
#
#     stations
# 0         45
# 1          9
# 2          4
# 3          4
# 4          4
# 5          4
# 6          4
# 7          2
# 8          2
# 9          2
# 10         2
# 11         2
# 12         0
# 13         0
# 14         0
# 15         0
# 16         0
# 17         0

# %%
print_fleet_df(market_vls[['city','bikes','stations']])
print('')
market_vls_final = (
    market_vls
    .assign(
        bikes=lambda x: x.bikes, #myround(x.bikes*1.1,10).astype(int),
        stations=lambda x: compute_stations_given_bikes(x.bikes).astype(int),
    )
)
market_vls_final.loc[market_vls_final['city']=='Jouy-en-Josas',['bikes','stations']] = [20,4]

print_fleet_df(market_vls_final[['city','bikes','stations']])
# Out:
#                           city  bikes  stations
# 1                   Versailles    250        45
# 2      Le Chesnay-Rocquencourt     50         9
# 3          Vélizy-Villacoublay     20         4
# 4                     Viroflay     20         4
# 5            Saint-Cyr-l'École     20         4
# 6                  Bois-d'Arcy     20         4
# 7         La Celle-Saint-Cloud     20         4
# 8                          Buc     10         2
# 9                Jouy-en-Josas     10         2
# 10          Fontenay-le-Fleury     10         2
# 11                Noisy-le-Roi     10         2
# 12                    Bougival     10         2
# 13                 Rennemoulin      0         0
# 14                 Châteaufort      0         0
# 15            Toussus-le-Noble      0         0
# 16          Les Loges-en-Josas      0         0
# 17                      Bailly      0         0
# 18                     Bièvres      0         0
# Total                             450        84
#
#                           city  bikes  stations
# 1                   Versailles    250        45
# 2      Le Chesnay-Rocquencourt     50         9
# 3          Vélizy-Villacoublay     20         4
# 4                     Viroflay     20         4
# 5            Saint-Cyr-l'École     20         4
# 6                  Bois-d'Arcy     20         4
# 7         La Celle-Saint-Cloud     20         4
# 8                          Buc     10         2
# 9                Jouy-en-Josas     20         4
# 10          Fontenay-le-Fleury     10         2
# 11                Noisy-le-Roi     10         2
# 12                    Bougival     10         2
# 13                 Rennemoulin      0         0
# 14                 Châteaufort      0         0
# 15            Toussus-le-Noble      0         0
# 16          Les Loges-en-Josas      0         0
# 17                      Bailly      0         0
# 18                     Bièvres      0         0
# Total                             460        86

# %%
market_vld_final = (
    market_vld
    .assign(
        # bikes=lambda x: np.where(x.bikes_max_2 > 15,myround(x.bikes_max_2*1.3,base=5),x.bikes_max_2).astype(int)
        # bikes = np.where(market_vld[['bikes_min','bikes_pop']].mean(axis=1)>5, round(market_vld[['bikes_min','bikes_pop']].mean(axis=1)),0
        # )
        )
    )

print_fleet_df(market_vld_final[['city','bikes']])
# Out:
#                           city  bikes
# 1                   Versailles    225
# 2      Le Chesnay-Rocquencourt     90
# 3          Vélizy-Villacoublay     50
# 4                     Viroflay     40
# 5            Saint-Cyr-l'École     40
# 6         La Celle-Saint-Cloud     40
# 7                  Bois-d'Arcy     25
# 8           Fontenay-le-Fleury     25
# 9                Jouy-en-Josas     10
# 10                    Bougival     10
# 11                 Châteaufort      0
# 12                         Buc      0
# 13                 Rennemoulin      0
# 14                Noisy-le-Roi      0
# 15                      Bailly      0
# 16          Les Loges-en-Josas      0
# 17            Toussus-le-Noble      0
# 18                     Bièvres      0
# Total                             555

# %% [markdown]
# ## Geography

# %% [markdown]
# <font color='#8db0f0'><b>France</b></font>

# %%
specific_place_name = get_specific_place_name(target_cities_df)
city = get_city(specific_place_name, local_crs)

# %% [markdown]
# <font color='#8db0f0'><b>Rest of the world</b></font>

# %% [raw]
# specific_place_name = ['Santiago,Chili'] # city center only
# # specific_place_name = ['Provincia de Santiago'] # entire city
#
# city = get_city(specific_place_name, local_crs)

# %%
city.plot(column='city_name',legend=True,figsize=(6,8),legend_kwds={'bbox_to_anchor': (1.5, 1)}).axis('off');

# %%
city.area * 1e-6
# Out:
# 0      6.645726
# 1      5.577729
# 2      2.763782
# 3      8.091231
# 4      5.832644
# 5      4.896461
# 6      7.142773
# 7      5.573351
# 8     10.227939
# 9      2.515124
# 10     5.552695
# 11     2.220388
# 12     5.106056
# 13     4.020408
# 14     8.947821
# 15    26.169200
# 16     3.486868
# 17     9.700067
# dtype: float64

# %% [markdown]
# ### H3

# %%
hex_resolution = 10

#Generate H3 hexagons
base = get_h3_fill(city,hex_resolution,local_crs)

#Plot
ax = base.plot(figsize=(8,8))
city.plot(ax=ax, color='None').axis('off');
# Out:
# C:\Users\FrancescoCusimano\anaconda3\envs\shiny\lib\site-packages\IPython\core\interactiveshell.py:3398: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\FrancescoCusimano\anaconda3\envs\shiny\lib\site-packages\IPython\core\interactiveshell.py:3398: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# No overlapping hexes.

# %% [markdown]
# ## External data

# %%
ox.settings.timeout = 1000

# %%
geo_data_dict = {}
geo_data_dict.update(get_lanes_data(specific_place_name))
geo_data_dict.update(get_bike_parking_data(specific_place_name))
geo_data_dict.update(get_transit_data(specific_place_name,country_code))
geo_data_dict.update(get_offices_data(specific_place_name))
geo_data_dict.update(get_destinations_data(specific_place_name,country_code))
geo_data_dict.update(get_population_data(city, data_dir_out, place, country_code))
# Out:
# Getting bike lanes... Done!
# Getting bike parking... Done!
# Getting transit...
# Found 11 train stations: Versailles-Château-Rive-Gauche, La Celle-Saint-Cloud, Noisy-le-Roi, Bièvres, Jouy-en-Josas, Porchefontaine, Versailles-Rive-Droite, Viroflay Rive Gauche, Montreuil, Allée Royale, Les Portes de Saint-Cyr
# Error when filtering query result for metro_stations
# Error when filtering query result for bus_stations
# Done!
# Getting offices... Done!
# Getting destinations...
# No townhalls found...
# Found 4 hospitals: Hôpital de Jour Bleuler, Hôpital privé de Parly 2 Le Chesnay, Hôpital André Mignot, Hôpital Richaud
# Found 8 universities: HEDAC, Université de Versailles Saint Quentin en Yvelines. Présidence. Services centraux, UVSQ - UFR des sciences, Lycée Professionel Jacques Prévert, École des Beaux Arts, Sorbonne Université - Campus de Saint-Cyr, Thales Université, Bâtiment - Bâtiment des Etudes (Batzet)
# Found 19 high schools: Lycée général et technologique privé Saint-Jean et Hulst, Lycée Général Hoche, Lycée d'Enseignement Général et Technologique Privé Cours Marie des Lys, Lycée franco-allemand, Lycée général et technologique privé Blanche de Castille, Lycée général et technologique Pierre Corneille, Lycée général et technologique Marie Curie, Lycée général et technologique La Bruyère, Lycée professionnel des métiers commercial Colbert, Lycée professionnel Jean Perrin, Lycée Jules Hardouin-Mansart, Lycée militaire de Saint-Cyr, Lycée professionnel Jean Moulin, Lycée professionnel Lucien René Duchesne, Lycée Polyvalent Jules Ferry, Lycée professionnel Jacques Prévert, École secondaire privée Jeanne d'Arc, Lycée Notre-Dame du Grandchamp, Lycée privé Sainte-Geneviève
# Done!
# Getting population... Done!

# %% [raw]
# to_remove_tuple = [
#     # ('hospitals', ['Priory Hospital Nottingham','Thorneywood']),
#     ('high_schools',["Lycée polyvalent Vincent D'Indy"])
#     # ('townhalls',['Mairie de Gaubert'])
# ]
#
# for category, names_to_remove in to_remove_tuple:
#     geo_data_dict[f'DESTINATIONS_{category}_PER_POINT'].data = geo_data_dict[f'DESTINATIONS_{category}_PER_POINT'].data.query("~name.isin(@names_to_remove)")

# %% [raw]
# for key in geo_data_dict.keys():
#     print(key)
#     print(geo_data_dict[key].data)

# %% [raw]
# del geo_data_dict['DESTINATIONS_hospitals_PER_POINT']

# %% [raw]
# del geo_data_dict['DESTINATIONS_high_schools_PER_POINT']
# # del geo_data_dict['DESTINATIONS_townhalls_PER_POINT']
# # del geo_data_dict['DESTINATIONS_universities_PER_POINT']

# %%
geo_data_dict.update(overall_h3_aggregation(geo_data_dict.copy(), base))
geo_data_dict.keys()
# Out:
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# c:\users\francescocusimano\documents\python_zoov_data\data-urban-analytics\urban_analytics\h3_utils.py:110: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geometry=lambda x: x.geometry.centroid,
# dict_keys(['LANES_ALL_PER_POINT', 'BIKE_PARKING_ALL_PER_POINT', 'TRANSIT_ALL_PER_POINT', 'TRANSIT_train_stations_PER_POINT', 'OFFICES_ALL_PER_POINT', 'DESTINATIONS_ALL_PER_POINT', 'DESTINATIONS_hospitals_PER_POINT', 'DESTINATIONS_universities_PER_POINT', 'DESTINATIONS_high_schools_PER_POINT', 'POPULATION_ALL_PER_POINT', 'LANES_ALL_PER_HEX', 'BIKE_PARKING_ALL_PER_HEX', 'TRANSIT_ALL_PER_HEX', 'TRANSIT_train_stations_PER_HEX', 'OFFICES_ALL_PER_HEX', 'DESTINATIONS_ALL_PER_HEX', 'DESTINATIONS_hospitals_PER_HEX', 'DESTINATIONS_universities_PER_HEX', 'DESTINATIONS_high_schools_PER_HEX', 'POPULATION_ALL_PER_HEX'])

# %% [markdown]
# ### Overall scoring

# %%
geo_data_dict.update(overall_h3_scoring(geo_data_dict,
                                        base.copy(),
                                        weights=[
                                            1, # Transit
                                            0.5, # Destinations
                                            0.5, # Lanes
                                            0.5, # Bike parking
                                            1, # Offices
                                            1, # Population
                                        ]))
# Out:
# Used weights:
# {'TRANSIT': 1, 'DESTINATIONS': 0.5, 'LANES': 0.5, 'BIKE_PARKING': 0.5, 'OFFICES': 1, 'POPULATION': 1}

# %%
geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data.describe()
# Out:
#        h3_res     area_km2        LANES  BIKE_PARKING      TRANSIT  \
# count  9222.0  9222.000000  9222.000000   9222.000000  9222.000000
# mean     10.0     0.013504     0.401837      0.066749     0.085893
# std       0.0     0.000009     1.183393      0.437669     0.379946
# min      10.0     0.013485     0.000000      0.000000     0.000000
# 25%      10.0     0.013496     0.000000      0.000000     0.000000
# 50%      10.0     0.013504     0.000000      0.000000     0.000000
# 75%      10.0     0.013511     0.000000      0.000000     0.000000
# max      10.0     0.013529    10.000000     10.000000    10.000000
#
#            OFFICES  DESTINATIONS   POPULATION        score
# count  9222.000000   9222.000000  9222.000000  9222.000000
# mean      0.036326      0.118067     0.316466     0.732011
# std       0.310296      0.491697     0.643209     1.421028
# min       0.000000      0.000000     0.000000     0.000000
# 25%       0.000000      0.000000     0.000000     0.000000
# 50%       0.000000      0.000000     0.002189     0.037856
# 75%       0.000000      0.000000     0.333864     0.919238
# max      10.000000     10.000000    10.000000    20.611974

# %%
geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data.plot(
    cmap='magma',
    column='score',
    edgecolor='none',
    legend=True,
    figsize=(12,8),
).axis('off');

# %%
geo_data_dict['POPULATION_ALL_PER_HEX'].data.POPULATION.sum()
# Out:
# 265658.2044815224

# %% [markdown]
# ## Station selection

# %%
poi_hexes = get_poi_hexes(geo_data_dict, hex_resolution,skip_categories=['high_schools'])
poi_hexes = filter_osm_hexes(poi_hexes, base, market_vls_final)
# Out:
# 11 train_stations
# 4 hospitals
# 8 universities
# Returning 23 unique hexe(s)

# %%
poi_hexes
# Out:
# []

# %%
manual_hexes = []

manual_coords = [
    # [50.753539499680556, 2.266749925606926], # gare st omer
]
manual_hexes  = get_manual_selection_hexes(manual_coords, hex_resolution)

manual_hexes.extend(manual_hexes)
manual_hexes.extend(poi_hexes)
manual_hexes
# Out:
# []

# %% [raw]
# # Modified function to remove the option 2 (need to rewrite function when time permits)
#
# def clustered_sites(
#     df: gpd.GeoDataFrame,
#     target: int,
#     score_col: str,
#     hex_col: str,
#     rank_col: str,
#     hex_resolution: int,
#     manual_selection: List[str] = [],
#     neighbors_list: List[str] = [],
#     max_distance: Optional[int] = None,
#     ascending: bool = False,
#     k: int = 1,
# ) -> Tuple[gpd.GeoDataFrame, List[str]]:
#     """
#     Selecting H3 sites based on an existing ranking without selecting contiguous sites.
#
#     target: number of sites to select
#     score_col: column with the score that will be used for the ranking
#     hex_col: column with the H3 index
#     rank_col: column with the revised site rankings
#     manual_selection: list of hexes to be selected regardless
#     max_distance: max distance allowed for a station to be valid (using weighted distance)
#     ascending: sorting method for the ranking
#     k: k neighbors to be set aside
#     #TODO: split into smaller functions, simplify
#     """
#
#     # initializing
#     neighbors = "k_ring_{}".format(k)
#     df[neighbors] = df[hex_col].apply(
#         lambda x: [h for h in list(k_ring(x, k)) if h != x]
#     )
#     df = (
#         df.sort_values(score_col, ascending=ascending)
#         .reset_index()
#         .drop(columns=["index", "level_0"], errors="ignore")
#     )
#     all_midpoint_selected_hexes = []
#     selected_stations_counter = 0
#     skiped_stations_counter = 0
#     intermediate_stations_counter = 0
#     df.loc[:, "selected"] = None
#
#     # check manual hex selection
#     if manual_selection is not None:
#         for i in list(df.loc[df.loc[:, hex_col].isin(manual_selection), :].index):
#             df.loc[i, "selected"] = True
#             df.loc[i, "backup"] = False
#             selected_stations_counter += 1
#             neighbors_list = list(set(neighbors_list + df.loc[i, neighbors]))
#
#     # looping
#     for i in range(0, len(df)):
#         if target > selected_stations_counter:
#             if df.loc[i, "selected"] == True:
#                 continue
#             else:
#                 if df.loc[i, hex_col] in set(neighbors_list):
#                     df.loc[i, "selected"] = False
#                     df.loc[i, "backup"] = True
#                     continue
#                 else:
#                     df.loc[i, "selected"] = True
#                     df.loc[i, "backup"] = False
#                     selected_stations_counter += 1
#                     neighbors_list = list(set(neighbors_list + df.loc[i, neighbors]))
#
#     # MAX DISTANCE LOGIC - remove the station and add another one that is closer to the network
#     if max_distance is not None:
#         df.loc[
#             df["selected"] == True, "dist_to_next_site"
#         ] = weighted_dist_to_next_site(df.loc[df["selected"] == True])
#         df1, neighbors_list1 = df.copy(), neighbors_list.copy()
#
#         # OPTION 1
#         current_max_distance = df1.loc[
#             df1["selected"] == True, "dist_to_next_site"
#         ].max()
#         while current_max_distance > max_distance:
#             print(f"Max distance exceeded! {round(current_max_distance)}m")
#             index_to_drop = (
#                 df1.loc[(df1["selected"] == True) & (~df1[hex_col].isin(manual_selection)), :]
#                 .sort_values("dist_to_next_site", ascending=False)
#                 .head(1)
#                 .index
#             )
#             skiped_stations_counter += 1
#             df1.loc[index_to_drop, "selected"] = False
#             df1.loc[index_to_drop, "backup"] = True
#
#             for i in df1.loc[
#                 (df1["selected"].isna()) & (~df1[hex_col].isin(neighbors_list1)), :
#             ].index:
#                 df1.loc[i, "selected"] = True
#                 df1.loc[i, "backup"] = False
#                 neighbors_list1 = list(set(neighbors_list1 + df1.loc[i, neighbors]))
#                 break
#             df1.loc[
#                 df1["selected"] == True, "dist_to_next_site"
#             ] = weighted_dist_to_next_site(df1.loc[df1["selected"] == True])
#             current_max_distance = df1.loc[
#                 df1["selected"] == True, "dist_to_next_site"
#             ].max()
#         score_df1 = df1[df1["selected"] == True].score.sum()
#
#         if (skiped_stations_counter == 0) & (intermediate_stations_counter == 0):
#             print("Max distance not reached")
#         else :
#             df = df1.copy()
#             print(
#                 f"Skipped {skiped_stations_counter} far away station(s)."
#             )
#             print(f"New current max distance {round(current_max_distance)}m")
#
#     # rank selected stations
#     df.loc[df["selected"] == True, rank_col] = df.loc[
#         df["selected"] == True, score_col
#     ].rank(method="max", ascending=ascending, na_option="bottom")
#
#     # rank backups and other sites that were not selected, in case we need them
#     # df.loc[df['selected']==False,rank_col] = target+df.loc[df['selected']==False,score_col].rank(
#     #     method='max',ascending=ascending,na_option='bottom')
#     # df[['backup','selected']] = df[['backup','selected']].fillna(False)
#
#     return df.sort_values(rank_col, ascending=True), neighbors_list

# %%
', '.join(market_vls_final.query("stations > 0").city.values)
# Out:
# "Versailles, Le Chesnay-Rocquencourt, Vélizy-Villacoublay, Viroflay, Saint-Cyr-l'École, Bois-d'Arcy, La Celle-Saint-Cloud, Buc, Jouy-en-Josas, Fontenay-le-Fleury, Noisy-le-Roi, Bougival"

# %%
import warnings
warnings.filterwarnings('ignore')

selected_sites = pd.DataFrame()
neighbors_list = []
for c in market_vls_final.city.unique():  
        print('\n====',c.upper(), '====')
        df_bs_sites,test = clustered_sites(
            geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data[geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data['city_name']==c],
            target= market_vls_final[market_vls_final['city']==c]['stations'].values[0],
            score_col='score',
            hex_col=f"hex{hex_resolution}",
            neighbors_list=neighbors_list,
            rank_col='site_rank',
            ascending=False,
            k=hex_k_mapper[hex_resolution],
            hex_resolution = hex_resolution,
            max_distance=2000,
            manual_selection=manual_hexes
        )
        selected_sites = selected_sites.append(df_bs_sites)
print("")
print(selected_sites.selected.value_counts(dropna=False))
selected_sites = selected_sites.query("selected == True")
# Out:
# ==== VERSAILLES ====
#
# Max distance not reached
#
# ==== LE CHESNAY-ROCQUENCOURT ====
#
# Max distance not reached
#
# ==== VÉLIZY-VILLACOUBLAY ====
#
# Max distance not reached
#
# ==== VIROFLAY ====
#
# Max distance not reached
#
# ==== SAINT-CYR-L'ÉCOLE ====
#
# Max distance not reached
#
# ==== BOIS-D'ARCY ====
#
# Max distance not reached
#
# ==== LA CELLE-SAINT-CLOUD ====
#
# Max distance not reached
#
# ==== BUC ====
#
# Max distance exceeded! 2010m
# Option 1 wins by 4.25 points. Skipped 1 far away station(s).
# New current max distance 1082m
#
# ==== JOUY-EN-JOSAS ====
#
# Max distance not reached
#
# ==== FONTENAY-LE-FLEURY ====
#
# Max distance not reached
#
# ==== NOISY-LE-ROI ====
#
# Max distance not reached
#
# ==== BOUGIVAL ====
#
# Max distance not reached
#
# ==== RENNEMOULIN ====
#
# Max distance not reached
#
# ==== CHÂTEAUFORT ====
#
# Max distance not reached
#
# ==== TOUSSUS-LE-NOBLE ====
#
# Max distance not reached
#
# ==== LES LOGES-EN-JOSAS ====
#
# Max distance not reached
#
# ==== BAILLY ====
#
# Max distance not reached
#
# ==== BIÈVRES ====
#
# Max distance not reached
#
# None     9011
# False     125
# True       86
# Name: selected, dtype: int64

# %% [markdown]
# ## Maps

# %%
# Check if stations placed == stations expected
assert_station_selection(selected_sites, market_vls_final)
# Out:
# All good, selected sites and market sizing match.
# True

# %%
# check if we have double stations
extra_stations = compute_stations_given_bikes(market_vls_final.bikes.sum()) - (len(selected_sites))
print(f"{round((extra_stations /len(selected_sites)),2)*100}% of the statsions have 20 bike spots.")
# Out:
# -3.0% of the statsions have 20 bike spots.

# %% [raw]
# geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data.query("score > score.quantile(.4)").score.mean()

# %%
add_Quicksand_font()

not_city = get_city_negative(city)

fig, ax = plt.subplots(1, 1, figsize=(10,10))
_ = ax.axis('off')

# reset zoom level (due to not_city box)
xlim, ylim = get_map_limits(city)
ax.set_xlim(xlim); ax.set_ylim(ylim)

geo_data_dict['FINAL_SCORE_ALL_PER_HEX'].data.query("score > score.quantile(.5)").plot(
    ax=ax,
    column='score',
    scheme="fisher_jenks_sampled", 
    k=7,
    cmap='Blues',
    edgecolor='none',
    alpha=.8
)

not_city.plot(
    ax=ax,
    color='white',
    edgecolor='none',
    alpha=.4,
)

city.plot(
    ax=ax,
    color='none',
    edgecolor='black',
    linewidth=.4,
    alpha=1
)

selected_sites.plot(
    ax=ax,
    color='red',
    edgecolor='none',
)

# LEGEND
## legend elements
hexagon1 = Line2D([0], [0], color='red', marker='h', linewidth=0, markersize=11, alpha=0.8)
line = Line2D([0], [0], color='black', linewidth=.6, markersize=1, alpha=1 ,label='a')
cmap_gradient = get_gradient_cmap()

## labels
if country_code == 'FR':
    labels = ["Potentiel emplacement station",'Score de demande latente', 'Limite commune'] 
else:
    labels = ['Bikeshare station', 'Bikeshare potential', 'City limit']
handles = [hexagon1,cmap_gradient,line]

add_legend(ax, labels, handles,title='Versailles Grand Parc', location='best')
add_city_names(city,font_size=6)
add_north_arrow(ax)
add_scalebar(ax)



# basemap 
cx.add_basemap(
    ax,
    crs=city.crs,
    source =cx.providers.Esri.WorldGrayCanvas ,#cx.providers.OpenStreetMap.Mapnik,# #cx.providers.Stamen.TonerLite, #cx.providers.Stamen.Toner ,
    attribution=False,
    attribution_size=7
)

plt.savefig(os.path.join(data_dir_out,f"{place.replace(' ','_')}_stations.png"),dpi=300,facecolor='w', bbox_inches='tight',)

# %%
# sanity check
m = selected_sites.drop('k_ring_2',axis=1).explore('site_rank',height='100%',width='100%')
city.explore(m=m,style_kwds={'fill':False})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f30079817a89f8d66258718176a18f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f30079817a89f8d66258718176a18f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f30079817a89f8d66258718176a18f07 = L.map(
#                 &quot;map_f30079817a89f8d66258718176a18f07&quot;,
#                 {
#                     center: [48.811500461897666, 2.114967959701593],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f30079817a89f8d66258718176a18f07);
#
#
#
#
#
#             var tile_layer_047d7853bcfcf05cf639255fe14ab733 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f30079817a89f8d66258718176a18f07);
#
#
#             map_f30079817a89f8d66258718176a18f07.fitBounds(
#                 [[48.75620197020856, 2.009835882418582], [48.866798953586766, 2.2201000369846033]],
#                 {}
#             );
#
#
#         function geo_json_2c4a72cc10180086ca1b4c6a7c1325b7_styler(feature) {
#             switch(feature.properties.hex10) {
#                 case &quot;8a1fb4614a4ffff&quot;: case &quot;8a1fb4633b87fff&quot;: case &quot;8a1fb461d8f7fff&quot;: case &quot;8a1fb4602aeffff&quot;: case &quot;8a1fb478d6d7fff&quot;: case &quot;8a1fb478c61ffff&quot;: case &quot;8a1fb4622487fff&quot;: case &quot;8a1fb4610037fff&quot;: case &quot;8a1fb461169ffff&quot;: case &quot;8a1fb478dd67fff&quot;: case &quot;8a1fb47a928ffff&quot;: case &quot;8a1fb4635a77fff&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb46330d7fff&quot;: case &quot;8a1fb4631487fff&quot;: case &quot;8a1fb46026d7fff&quot;: case &quot;8a1fb4602847fff&quot;: case &quot;8a1fb478d767fff&quot;: case &quot;8a1fb478cc97fff&quot;: case &quot;8a1fb4622daffff&quot;: case &quot;8a1fb4611487fff&quot;:
#                     return {&quot;color&quot;: &quot;#471164&quot;, &quot;fillColor&quot;: &quot;#471164&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb4615c5ffff&quot;: case &quot;8a1fb4631da7fff&quot;: case &quot;8a1fb461c157fff&quot;: case &quot;8a1fb4602c27fff&quot;: case &quot;8a1fb4632daffff&quot;: case &quot;8a1fb4781647fff&quot;: case &quot;8a1fb46318a7fff&quot;: case &quot;8a1fb4613267fff&quot;:
#                     return {&quot;color&quot;: &quot;#481a6c&quot;, &quot;fillColor&quot;: &quot;#481a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb4615d97fff&quot;: case &quot;8a1fb463392ffff&quot;:
#                     return {&quot;color&quot;: &quot;#482173&quot;, &quot;fillColor&quot;: &quot;#482173&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb461594ffff&quot;: case &quot;8a1fb46308effff&quot;:
#                     return {&quot;color&quot;: &quot;#482979&quot;, &quot;fillColor&quot;: &quot;#482979&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb4610997fff&quot;: case &quot;8a1fb46302effff&quot;:
#                     return {&quot;color&quot;: &quot;#472f7d&quot;, &quot;fillColor&quot;: &quot;#472f7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb4615d2ffff&quot;: case &quot;8a1fb4631cd7fff&quot;:
#                     return {&quot;color&quot;: &quot;#453781&quot;, &quot;fillColor&quot;: &quot;#453781&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a1fb4633067fff&quot;: case &quot;8a1fb4630267fff&quot;:

# %% [markdown]
# ## Exports
# #### Google MyMaps

# %%
import fiona

# %%
fiona.supported_drivers['KML'] = 'rw'
selected_sites[['geometry','site_rank','city_name',f"hex{hex_resolution}"]].to_file(os.path.join(data_dir_out,place+'_stations.kml'), driver='KML')

city_boundary = city.copy()#.query("city_name.isin(@curr_city)").copy()
city_boundary.geometry = city_boundary.boundary
city_boundary[['geometry','city_name']].to_file(os.path.join(data_dir_out,place+'_city.kml'), driver='KML')

# %%
from IPython.display import Markdown as md

if country_code == 'FR':
    output = (
        f"{place} - Proposition Réseau VLS\n\n"
        # f"Proposition de maillage pour un réseau VLS dans les villes de {target_city_name} et {(', ').join([x for i,x in enumerate(city_subset) if x!=target_city_name])}.\n\n"
        'Emplacement approx. stations VLS\n\n'
        'Limites communes\n\n'
    )
else:
    output = (
        f"{place} - Bike Share Network Proposal\n\n"
        # f"Proposal for a bike share network in the city of {target_city_name} and {(', ').join([x for i,x in enumerate(city_subset) if x!=[target_city_name]])}.\n\n"
        'Approx. bike station location\n\n'
        'City boundary'
    )
    
md(output)
# Out:
# Versailles - Proposition Réseau VLS
#
# Emplacement approx. stations VLS
#
# Limites communes

# %% [markdown]
# #### Slack message

# %%
if country_code == 'FR':
    output = (
        f"__{place} Demand Assessment__\n\n"
        ">__Périmètre:__\n\n"
        f"{(', ').join(market_vls_final.city.unique())}\n\n"
        ">__Taille de flotte__ (détail par ville ci-dessous)\n\n"
        f"- VLD : {market_vld_final.bikes.sum()} vélos\n\n"
        f"- VLS : {market_vls_final.bikes.sum()} vélos / {market_vls_final.stations.sum()} stations\n\n"
        ">__Détail interdistance__ (en mètres)\n\n"
        ">__Couverture population__ (approximative)\n\n"
        ">__Cartes__\n\n"
        f"- Cartes statiques ci-jointes\n\n"
        f"- Carte Google MyMaps (lien)\n\n"
    )
else:
    output = (
        f"__{place} Demand Assessment__\n\n"
        ">__Area of study:__\n\n"
        # f"{(', ').join(target_cities)}\n\n"
        ">__Fleet sizing__ (detail by city below)\n\n"
        f"- VLD : {market_vld.bikes.sum()} bikes\n\n"
        f"- VLS : {market_vls_final.bikes.sum()} bikes / {market_vls_final.stations.sum()} stations\n\n"
        ">__Distance between stations__ (in meters)\n\n"
        ">__Population coverage__\n\n"
        ">__Maps__\n\n"
        f"- Static map attached\n\n"
        f"- Google MyMaps (link)\n\n"
        # f"{selected_sites['dist_to_next_site'].describe()[['count','mean','min','max']]}"
    )

md(output)
# Out:
# __Versailles Demand Assessment__
#
# >__Périmètre:__
#
# Versailles, Le Chesnay-Rocquencourt, Vélizy-Villacoublay, Viroflay, Saint-Cyr-l'École, Bois-d'Arcy, La Celle-Saint-Cloud, Buc, Jouy-en-Josas, Fontenay-le-Fleury, Noisy-le-Roi, Bougival, Rennemoulin, Châteaufort, Toussus-le-Noble, Les Loges-en-Josas, Bailly, Bièvres
#
# >__Taille de flotte__ (détail par ville ci-dessous)
#
# - VLD : 555 vélos
#
# - VLS : 460 vélos / 86 stations
#
# >__Détail interdistance__ (en mètres)
#
# >__Couverture population__ (approximative)
#
# >__Cartes__
#
# - Cartes statiques ci-jointes
#
# - Carte Google MyMaps (lien)

# %% [markdown]
# #### Distance between stations

# %%
with pd.option_context('float_format', '{:.2f}'.format): 
    print(weighted_dist_to_next_site(selected_sites, weights=[1,0])
          .describe()[['count','mean','min','max']]
          .to_frame(''))
# Out:
#
# count   86.00
# mean   414.59
# min     65.00
# max   1684.00

# %% [markdown]
# #### Population coverage

# %%
for buffer in [400, 1000]:
    if country_code == 'FR': 
        print(f"Population à moins de {buffer}m d'une station : {get_pop_coverage(selected_sites, geo_data_dict['POPULATION_ALL_PER_POINT'].data, local_crs, buffer=buffer):,}")
    else :
        print(f"People living less than {buffer}m from a station : {get_pop_coverage(selected_sites, geo_data_dict['POPULATION_ALL_PER_POINT'].data, local_crs, buffer=buffer)}")
# Out:
# Population à moins de 400m d'une station : 192,527
# Population à moins de 1000m d'une station : 253,970

# %% [raw]
# print("VLD market sizing")
# print(tabulate(add_total_row(market_vld_final[['city','bikes']]),headers='keys',tablefmt = 'simple'))

# %% [raw]
# print("VLS market sizing")
# print(tabulate(add_total_row(market_vls_final[['city','bikes','stations']]),headers='keys',tablefmt = 'simple'))
