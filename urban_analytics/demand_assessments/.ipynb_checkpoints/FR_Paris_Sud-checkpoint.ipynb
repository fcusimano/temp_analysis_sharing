# %% [raw]
# ---
# title: 'Royan-Cognac-Angoulême'
# date: last-modified
# categories: 'France'
# ---

# %%
from urban_analytics.utils import *
from urban_analytics.imports import *
from urban_analytics.geography import *
from urban_analytics.fleet_sizing import *
from urban_analytics.h3_utils import *
from urban_analytics.osm import *
from urban_analytics.scoring import *
from urban_analytics.population import *
from urban_analytics.station_selection import *
from urban_analytics.maps import *
from urban_analytics.predictions import *

import fiona
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from sklearn.preprocessing import MinMaxScaler
from IPython.display import Markdown
from dash import Dash, html, dcc
from dash.dependencies import Input, Output
import warnings

warnings.filterwarnings("ignore")

init_notebook_mode(connected=True)
plotly.offline.init_notebook_mode(connected=True)
from matplotlib.lines import Line2D
import contextily as cx

# %load_ext lab_black
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
place = "Paris Sud"
country_code = "FR"

local_crs = LocalCRS[country_code].value
data_dir_in, data_dir_out = set_up_directories(country_code, place)
# Out:
# data_dir_in already exists
# data_dir_out already exists

# %%
# | output: true
if country_code == "FR":
    display(Markdown("# Étude de territoire\n\n"))
else:
    display(Markdown("# Demand Assessment\n\n"))
# Out:
# # Étude de territoire

# %%
display(
    Markdown(
        f"""
## Fleet sizing
### VLS market
"""
    )
)
# Out:
# ## Fleet sizing
# ### VLS market

# %%
target_city_name = [
    "Saclay",
    "Antony",
    "Jouy-en-Josas",
    "Saint-Rémy-lès-Chevreuse",
]  # main cities
city_subset = [
    "Antony",
    "Massy",
    "Palaiseau",
    "Sceaux",
    "Verrières-le-Buisson",
    "Igny",
    "Gif-sur-Yvette",
    "Orsay",
    "Bures-sur-Yvette",
    "Bourg-la-Reine",
    "Villebon-sur-Yvette",
    "Saclay",
    "Chatenay Malabry",
    "Le Plessis-Robinson",
    "Fontenay-aux-roses",
]  # keep only these

# %%
target_cities_df = get_city_selection_df(
    target_city_name=target_city_name,
    city_subset=city_subset,
)
# Out:
# All cities found (15)
# 2 area(s) (CA Communauté Paris-Saclay,Métropole du Grand Paris)

# %%
market_vls = get_vls_fleet(target_cities_df, batches=10)
market_vls.reset_index(inplace=True)
market_vls.rename(columns={"index": "CODGEO"}, inplace=True)
market_vls.sort_values("rounded_bikes", ascending=False).head(20)
# Out:
#     CODGEO                LIBGEO       city_name_plain  \
# 0    34517                Antony                antony
# 1    34426                 Massy                 massy
# 2    34452             Palaiseau             palaiseau
# 3    34523      Châtenay-Malabry      chatenay malabry
# 4    34542   Le Plessis-Robinson   le plessis robinson
# 5    34400        Gif-sur-Yvette        gif sur yvette
# 6    34530    Fontenay-aux-Roses    fontenay aux roses
# 7    34450                 Orsay                 orsay
# 8    34499  Verrières-le-Buisson  verrieres le buisson
# 9    34522        Bourg-la-Reine        bourg la reine
# 10   34546                Sceaux                sceaux
# 11   34360      Bures-sur-Yvette      bures sur yvette
# 12   34409                  Igny                  igny
# 13   34505   Villebon-sur-Yvette   villebon sur yvette
# 14   34466                Saclay                saclay
#
#                        LIBEPCI DEP        dep_name  population  area_km2  REG  \
# 0     Métropole du Grand Paris  92  Hauts-de-Seine       62760      9.56   11
# 1   CA Communauté Paris-Saclay  91         Essonne       50644      9.43   11
# 2   CA Communauté Paris-Saclay  91         Essonne       35236     11.51   11
# 3     Métropole du Grand Paris  92  Hauts-de-Seine       34021      6.38   11
# 4     Métropole du Grand Paris  92  Hauts-de-Seine       30061      3.43   11
# 5   CA Communauté Paris-Saclay  91         Essonne       21007     11.60   11
# 6     Métropole du Grand Paris  92  Hauts-de-Seine       25531      2.51   11
# 7   CA Communauté Paris-Saclay  91         Essonne       15503      7.97   11
# 8   CA Communauté Paris-Saclay  91         Essonne       14888      9.91   11
# 9     Métropole du Grand Paris  92  Hauts-de-Seine       21050      1.86   11
# 10    Métropole du Grand Paris  92  Hauts-de-Seine       20004      3.60   11
# 11  CA Communauté Paris-Saclay  91         Essonne        9408      4.17   11
# 12  CA Communauté Paris-Saclay  91         Essonne        9917      3.82   11
# 13  CA Communauté Paris-Saclay  91         Essonne       10466      7.41   11
# 14  CA Communauté Paris-Saclay  91         Essonne        4256     13.65   11
#
#       region_name  ...  surplus_workers  final_pop_coeff  final_cycl_coeff  \
# 0   Île-de-France  ...                0         1.311012          2.164617
# 1   Île-de-France  ...             3902         1.592451          2.126159
# 2   Île-de-France  ...                0         1.498974          1.930403
# 3   Île-de-France  ...                0         1.119462          0.803032
# 4   Île-de-France  ...                0         1.471261          1.021739
# 5   Île-de-France  ...              215         1.489634          1.885587
# 6   Île-de-France  ...                0         1.149115          1.759000
# 7   Île-de-France  ...             2975         1.839280          1.730921
# 8   Île-de-France  ...                0         1.039882          1.350428
# 9   Île-de-France  ...                0         1.261681          1.842132
# 10  Île-de-France  ...                0         1.192310          2.639894
# 11  Île-de-France  ...                0         1.106349          2.238908
# 12  Île-de-France  ...                0         1.098176          0.959230
# 13  Île-de-France  ...             1877         1.463620          1.401621
# 14  Île-de-France  ...             3001         2.232246          1.449553
#
#     fub_score   cost_km  bike_replacement_Y  O_trips_from_tourism  \
# 0    3.168048  0.057902            0.035631                  3403
# 1    3.497288  0.057902            0.035631                 21187
# 2    3.001234  0.057902            0.035631                 14662
# 3    2.264721  0.057902            0.035631                  2490
# 4    2.690403  0.057902            0.035631                  1664
# 5    3.546416  0.057902            0.035631                  2781
# 6    2.602670  0.057902            0.035631                   738
# 7    2.919354  0.057902            0.035631                   784
# 8    2.999491  0.057902            0.035631                   577
# 9    3.421724  0.057902            0.035631                   488
# 10   3.490984  0.057902            0.035631                   613
# 11   3.568581  0.057902            0.035631                  5178
# 12   3.241456  0.057902            0.035631                  2293
# 13   2.439928  0.057902            0.035631                   784
# 14   3.191401  0.057902            0.035631                  4187
#
#     P_trips_from_tourism  rounded_bikes  stations
# 0                   2314            190        34
# 1                  14407            150        27
# 2                   9970            100        18
# 3                   1693             90        16
# 4                   1131             80        14
# 5                   1891             60        11
# 6                    502             60        11
# 7                    533             50         9
# 8                    392             50         9
# 9                    332             50         9
# 10                   417             50         9
# 11                  3521             30         5
# 12                  1559             30         5
# 13                   533             30         5
# 14                  2847             20         4
#
# [15 rows x 41 columns]

# %%
display(
    Markdown(
        f"""
### VLD market
"""
    )
)
# Out:
# ### VLD market

# %%
target_cities_df_VLD = target_cities_df.copy()
target_cities_df_VLD.rename(
    columns={"LIBGEO": "city_name", "DEP": "dept_id"}, inplace=True
)
market_vld = get_vld_fleet(target_cities_df_VLD, batches=5)
print("Recommended long bike rental fleet size by city:")
print(
    f"{len(market_vld)} cities and {int(market_vld.bikes_lower.sum())}-{int(market_vld.bikes_upper.sum())} bikes"
)
print_fleet_df(
    market_vld[
        [
            "city",
            "bikes",
        ]
    ]
)
vld_bikes = market_vld["bikes"].sum()
# Out:
# Recommended long bike rental fleet size by city:
# 3 cities and 75-275 bikes
#             city  bikes
# 1      Angoulême    140
# 2          Royan     25
# 3         Cognac     10
# Total               175

# %%
display(Markdown(f"## Geography"))
# Out:
# ## Geography

# %%
specific_place_name = get_specific_place_name(target_cities_df)
city = get_city(specific_place_name, local_crs)

# %%
city.plot(
    column="city_name",
    legend=False,
    figsize=(6, 8),
    legend_kwds={"bbox_to_anchor": (1.5, 1)},
).axis("off")
# Out:
# (632610.1907391499, 651370.3808922189, 6841233.786956715, 6856077.514956562)

# %%
display(Markdown(f"### H3"))
# Out:
# ### H3

# %%
hex_resolution = 10

# Generate H3 hexagons
base = get_h3_fill(city, hex_resolution, local_crs)

# Plot
ax = base.plot(figsize=(8, 8))
city.plot(ax=ax, color="None").axis("off")
# Out:
# No overlapping hexes.
# (632607.370911836, 651429.5972658106, 6841182.817969138, 6856079.942051209)

# %%
display(Markdown(f"### External data"))
# Out:
# ### External data

# %%
ox.settings.timeout = 1000

# %%
geo_data_dict = {}
geo_data_dict.update(get_lanes_data(specific_place_name))
geo_data_dict.update(get_bike_parking_data(specific_place_name))
geo_data_dict.update(get_transit_data(specific_place_name, country_code))
geo_data_dict.update(get_offices_data(specific_place_name))
geo_data_dict.update(get_destinations_data(specific_place_name, country_code))
geo_data_dict.update(get_population_data(city, data_dir_out, place, country_code))
# Out:
# Getting bike lanes... Done!
# Getting bike parking... Done!
# Getting transit...
# Found 5 train stations: Massy-Palaiseau, Massy Verrières, Igny, Chemin d'Antony, Massy-TGV
# No metro stations found...
# Found 6 bus stations: Gare Routière de Gif-sur-Yvette, Gare d'Orsay Ville RER, Gare Routière Atlantis - Massy-Palaiseau, Gare Routière Vilmorin - Massy Palaiseau, Antony RER, Gare Routière Provisoire Massy RER B
# Done!
# Getting offices... Done!
# Getting destinations...
# Found 25 townhalls: Mairie d'Igny, nan, Mairie Annexe, Fontenay-aux-Roses, Mairie Annexe Pajeaud, Mairie Annexe, Annexe de la Mairie, Annexe Saint-Exupéry, Mairie Annexe, Mairie annexe de Gif-sur-Yvette, nan, nan, Mairie de Bures-sur-Yvette, Mairie, Mairie d'Orsay, Mairie annexe Val d'Albian, Mairie de Saclay, Mairie du Plessis-Robinson, Mairie de Massy, Mairie, Hôtel de ville de Palaiseau, Mairie de Bourg-la-Reine, Hôtel de ville d'Antony, Mairie, Hôtel de Ville de Villebon-sur-Yvette
# Found 4 hospitals: Hôpital privé Jacques Cartier, Centre hospitalier d'Orsay, Hôpital Psychiatrique Erasme, Hôpital Privé d'Antony
# Found 15 universities: Université Paris-Saclay - Campus Vallée, Ensta ParisTech Laboratoires, IUT de Sceaux, Institut des Hautes Études Scientifiques, Centre sportif du Moulon, Réduit de Verrières, Bâtiment S, École Polytechnique - IP Paris, Faculté de pharmacie, AgroParisTech - INRAE - Campus Agro Paris-Saclay, Faculté de Pharmacie, Biologie et Chimie de l'Université Paris-Saclay, Institut Mines Télécom - Institut Polytechnique de Paris, IUT d'Orsay, Faculté Jean-Monnet Droit-Économie-Gestion - Université Paris-Saclay, Université Paris-Saclay
# Found 21 high schools: Lycée général et technologique privé Île de France, Lycée général Marie Curie, Lycée général et technologique privé Sainte-Marie La Croix, Lycée professionnel Florian, Cité scolaire Lakanal, Lycée polyvalent Henri Poincaré, Lycée général et technologique Vallée de Chevreuse, Collège et Lycée Descartes, Lycée général et technologique Emmanuel Mounier, Lycée Polyvalent Saint-Martin, Lycée général et technologique Blaise Pascal, Lycée professionnel Saint-François d'Assise, Lycée général et technologique Camille Claudel, Lycée polyvalent Parc de Vilgenis, Lycée Fustel de Coulanges, Lycée professionnel Gustave Eiffel, Lycée Horticole Saint-Nicolas, Lycée Polyvalent Jean Jaurès, Lycée Notre-Dame, Lycée International de Palaiseau Paris Saclay, Lycée privé du Cours Secondaire d'Orsay
# Done!
# Getting population... Done!

# %%
to_remove_tuple = [
    # (
    #    "DESTINATIONS",
    #    "hospitals",
    #    ["Hôpital de la Cavale Blanche"],
    # )   ,
    (
        "DESTINATIONS",
        "townhalls",
        [
            "Préfecture",
            "Hôtel de ville Cognac",
        ],
    ),
    # (
    #    "DESTINATIONS",
    #    "universities",
    #    [
    #        "IFSI de Perray-Vaucluse - Université Paris-Saclay",
    #        "IFSI de Perray-Vaucluse",
    #    ],
    # ),
    # (
    #    "TRANSIT",
    #    "train_stations",
    #    ["Breuillet - Village", "Corbeil-Essonnes", "Athis-Mons", "Savigny-sur-Orge"],
    # ),
    # (
    #    "TRANSIT",
    #    "bus_stations",
    #    [
    #        "Saint-Michel-sur-Orge RER",
    #        "Gare de Sainte-Geneviève des Bois RER C",
    #        "Évry-Courcouronnes Centre",
    #        "Gare RER C de Savigny-sur-Orge",
    #        "Gare de Mennecy - Place de la Gare",
    #    ],
    # ),
]

for category, subcategory, names_to_remove in to_remove_tuple:
    geo_data_dict[f"{category}_{subcategory}_PER_POINT"].data = geo_data_dict[
        f"{category}_{subcategory}_PER_POINT"
    ].data.query("~name.isin(@names_to_remove)")

# %%
warnings.filterwarnings("ignore")

geo_data_dict.update(overall_h3_aggregation(geo_data_dict.copy(), base))
geo_data_dict.keys()
# Out:
# dict_keys(['LANES_ALL_PER_POINT', 'BIKE_PARKING_ALL_PER_POINT', 'TRANSIT_ALL_PER_POINT', 'TRANSIT_train_stations_PER_POINT', 'TRANSIT_bus_stations_PER_POINT', 'OFFICES_ALL_PER_POINT', 'DESTINATIONS_ALL_PER_POINT', 'DESTINATIONS_townhalls_PER_POINT', 'DESTINATIONS_universities_PER_POINT', 'DESTINATIONS_high_schools_PER_POINT', 'POPULATION_ALL_PER_POINT', 'LANES_ALL_PER_HEX', 'BIKE_PARKING_ALL_PER_HEX', 'TRANSIT_ALL_PER_HEX', 'TRANSIT_train_stations_PER_HEX', 'TRANSIT_bus_stations_PER_HEX', 'OFFICES_ALL_PER_HEX', 'DESTINATIONS_ALL_PER_HEX', 'DESTINATIONS_townhalls_PER_HEX', 'DESTINATIONS_universities_PER_HEX', 'DESTINATIONS_high_schools_PER_HEX', 'POPULATION_ALL_PER_HEX'])

# %%
display(Markdown(f"### Overall scoring"))
# Out:
# ### Overall scoring

# %%
geo_data_dict.update(
    overall_h3_scoring(
        geo_data_dict,
        base.copy(),
        weights=[
            1,  # Transit
            1,  # Destinations
            0.5,  # Lanes
            0.5,  # Bike parking
            1,  # Offices
            1,  # Population
        ],
    )
)
# Out:
# Used weights:
# {'TRANSIT': 1, 'DESTINATIONS': 1, 'LANES': 0.5, 'BIKE_PARKING': 0.5, 'OFFICES': 1, 'POPULATION': 1}

# %%
geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data.plot(
    cmap="magma",
    column="score",
    edgecolor="none",
    legend=True,
    figsize=(12, 8),
).axis("off")
# Out:
# (379390.85257389874, 486081.85641571484, 6505747.417034099, 6519235.882151223)

# %%
total_pop = geo_data_dict["POPULATION_ALL_PER_HEX"].data.POPULATION.sum()
total_pop
# Out:
# 74709.95561253576

# %%
display(Markdown(f"### Station selection"))
# Out:
# ### Station selection

# %%
poi_hexes = get_poi_hexes(
    geo_data_dict,
    hex_resolution,
    skip_categories=["high_schools", "bus_stations", "universities"],
)
poi_hexes = filter_poi_hexes(poi_hexes, base, market_vls)
poi_hexes
# Out:
# 3 train_stations
# 2 townhalls
# Returning 5 unique hexe(s)
# ['8a186b815b57fff',
#  '8a186bc0c6b7fff',
#  '8a186a2daad7fff',
#  '8a186a2d8a9ffff',
#  '8a186b80655ffff']

# %%
manual_hexes = []
manual_coords = [
    [45.6898535011106, -0.32903816434256317],  # cognac centre collèges
    [45.64968504350128, 0.1443890671627371],  # angoulème centre ouest
]
manual_coords_hexes = get_manual_selection_hexes(manual_coords, hex_resolution)
manual_hexes.extend(manual_coords_hexes)
manual_hexes.extend(poi_hexes)
manual_hexes
# Out:
# ['8a186bc0eb27fff',
#  '8a186b81502ffff',
#  '8a186b815b57fff',
#  '8a186bc0c6b7fff',
#  '8a186a2daad7fff',
#  '8a186a2d8a9ffff',
#  '8a186b80655ffff']

# %%
warnings.filterwarnings("ignore")

hex_k_mapper = {9: 1, 10: 3}  # CAREFUL WITH THIS

selected_sites = pd.DataFrame()
neighbors_list = []
for c in market_vls.LIBGEO.unique():
    print("\n====", c.upper(), "====")
    df_bs_sites, neighbors_list = clustered_sites(
        geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data[
            geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data["city_name"] == c
        ],
        target=market_vls[market_vls["LIBGEO"] == c]["stations"].values[0],
        score_col="score",
        hex_col=f"hex{hex_resolution}",
        neighbors_list=neighbors_list,
        rank_col="site_rank",
        ascending=False,
        k=hex_k_mapper[hex_resolution],
        hex_resolution=hex_resolution,
        max_distance=1500,  # RESET THIS AT 2000 OR 1000 FOR NEXT DEMAND ASSESSMENT
        manual_selection=manual_hexes,
    )
    selected_sites = selected_sites.append(df_bs_sites)
print("")
print(selected_sites.selected.value_counts(dropna=False))
selected_sites = selected_sites.query("selected == True")
# Out:
# ==== ANGOULÊME ====
#
# Max distance exceeded! 1688m
# Option 2 wins by 1.84 points. Placed 1 intermediate station(s).
# New current max distance 1112m
#
# ==== ROYAN ====
#
# Max distance not reached
#
# ==== COGNAC ====
#
# Max distance exceeded! 1616m
# Option 1 wins by 2.39 points. Skipped 1 far away station(s).
# New current max distance 1101m
#
# None     3827
# False      49
# True       26
# Name: selected, dtype: int64

# %%
display(Markdown(f"## Traffic predictions per stations"))
# Out:
# ## Traffic predictions per stations

# %%
# method to calculate trips per station, from total expected trips gotten from model

# selected_sites["score_ratio"] = selected_sites["score"] / selected_sites["score"].sum()

# P_low_trips = market_vls["P_low_price_trips_Y"].sum()
# O_low_trips = market_vls["O_low_price_trips_Y"].sum()
# P_med_trips = market_vls["P_med_price_trips_Y"].sum()
# O_med_trips = market_vls["O_med_price_trips_Y"].sum()
# P_high_trips = market_vls["P_high_price_trips_Y"].sum()
# O_high_trips = market_vls["O_high_price_trips_Y"].sum()

# for scenario in ["P", "O"]:
#     for price_range in ["low", "med", "high"]:
#         selected_sites[f"station_{scenario}_{price_range}_trips"] = selected_sites[
#             "score_ratio"
#         ] * eval(f"{scenario}_{price_range}_trips")

# %%
expected_station_number = compute_stations_given_bikes(market_vls.rounded_bikes.sum())
extra_stations = expected_station_number - (len(selected_sites))

print(f"We have {expected_station_number} expected stations given our bike fleet size.")
print(f"We have selected {len(selected_sites)} stations for our demand assessment.")
print(
    f"Hence, {round((extra_stations /len(selected_sites)),2)*100}% of the proposed stations will have 20 bike spots."
)
print(f"{extra_stations} of the stations will have 20 bike spots.")
print(f"{len(selected_sites)-extra_stations} of the stations will have 10 bike spots.")
# Out:
# We have 29 expected stations given our bike fleet size.
# We have selected 26 stations for our demand assessment.
# Hence, 12.0% of the proposed stations will have 20 bike spots.
# 3 of the stations will have 20 bike spots.
# 23 of the stations will have 10 bike spots.

# %%
train_stations_hexes = get_poi_hexes(
    geo_data_dict,
    hex_resolution,
    skip_categories=["high_schools", "bus_stations", "universities", "townhalls"],
)
train_stations_hexes
# Out:
# 3 train_stations
# Returning 3 unique hexe(s)
# ['8a186bc0c6b7fff', '8a186a2d8a9ffff', '8a186b80655ffff']

# %%
selected_sites["Overall_Rank"] = selected_sites["score"].rank(ascending=0).astype(int)
# selected_sites = selected_sites.assign(
#    bike_spots=np.where(
#        selected_sites.Overall_Rank <= extra_stations,
#        20,
#        10,
#    )
# )
selected_sites = selected_sites.assign(
    bike_spots=np.where(
        selected_sites["hex10"].isin(train_stations_hexes),
        20,
        10,
    )
)
selected_sites_20 = selected_sites[selected_sites["bike_spots"] == 20]
selected_sites_10 = selected_sites[selected_sites["bike_spots"] == 10]
print(len(selected_sites_20))
print(len(selected_sites_10))
# Out:
# 3
# 23

# %%
selected_sites[
    (selected_sites["city_name"] == "Royan") & (selected_sites["bike_spots"] == 10)
]
# Out:
#                hex10                                           geometry  \
# 0    8a186a2d8617fff  POLYGON ((386047.738 6510765.819, 385978.445 6...
# 3    8a186a2d8457fff  POLYGON ((385979.965 6511374.382, 385910.672 6...
# 5    8a186a2d8777fff  POLYGON ((386463.483 6510884.775, 386394.194 6...
# 15   8a186a2da02ffff  POLYGON ((384571.403 6511180.747, 384502.098 6...
# 19   8a186a2dbd07fff  POLYGON ((385708.289 6510389.591, 385638.993 6...
# 31   8a186a2d8cd7fff  POLYGON ((386243.079 6512007.815, 386173.790 6...
# 382  8a186a2daad7fff  POLYGON ((385054.988 6510691.099, 384985.687 6...
#
#     city_name  h3_res  area_km2     LANES  BIKE_PARKING   TRANSIT  OFFICES  \
# 0       Royan      10  0.014504  0.000000           2.0  0.000000    10.00
# 3       Royan      10  0.014504  3.346050           0.0  3.333333     6.25
# 5       Royan      10  0.014503  0.000000           4.0  1.666667     2.50
# 15      Royan      10  0.014508  2.564667           0.0  0.000000     3.75
# 19      Royan      10  0.014506  3.330933           4.0  2.500000     2.50
# 31      Royan      10  0.014503  0.000000           0.0  3.333333     0.00
# 382     Royan      10  0.014507  0.000000           0.0  0.000000     0.00
#
#      DESTINATIONS  POPULATION      score  \
# 0        6.111111    4.310907  21.422019
# 3        3.055556    3.210589  17.522503
# 5        8.055556    2.292166  16.514388
# 15       5.277778    1.560227  11.870338
# 19       1.666667    0.847976  11.180109
# 31       1.111111    4.373015   8.817460
# 382      1.388889    0.382812   1.771701
#
#                                               k_ring_3 selected backup  \
# 0    [8a186a2d8717fff, 8a186a2d8697fff, 8a186a2d87a...     True  False
# 3    [8a186a2d840ffff, 8a186a2d8717fff, 8a186a2d841...     True  False
# 5    [8a186a2d8717fff, 8a186a2d87affff, 8a186a2d808...     True  False
# 15   [8a186a2da01ffff, 8a186a2da0c7fff, 8a186a2da17...     True  False
# 19   [8a186a2d8697fff, 8a186a2dbc2ffff, 8a186a2dbd5...     True  False
# 31   [8a186a2d8c17fff, 8a186a2d8537fff, 8a186a2d850...     True  False
# 382  [8a186a2da227fff, 8a186a2daa0ffff, 8a186a2da30...     True  False
#
#      dist_to_next_site  dist_to_far_away_station  site_rank  Overall_Rank  \
# 0                401.0                       NaN        1.0             1
# 3                575.5                       NaN        2.0             2
# 5                485.5                       NaN        3.0             3
# 15               960.0                       NaN        4.0             5
# 19               545.0                       NaN        5.0             9
# 31               843.0                       NaN        6.0            15
# 382              629.5                       NaN        8.0            26
#
#      bike_spots
# 0            10
# 3            10
# 5            10
# 15           10
# 19           10
# 31           10
# 382          10

# %%
display(Markdown(f"## Maps"))
# Out:
# ## Maps

# %%
add_Quicksand_font()

not_city = get_city_negative(royan_city)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
_ = ax.axis("off")

# reset zoom level (due to not_city box)
xlim, ylim = get_map_limits(royan_city)

# xlim = [823630.250588381, 838316.024679207]
# ylim = [6279944.366917977, 6294579.44074818]

ax.set_xlim(xlim)
ax.set_ylim(ylim)

geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data.query("score > score.quantile(.8)").plot(
    ax=ax,
    column="score",
    scheme="fisher_jenks_sampled",
    k=7,
    cmap="Blues",
    edgecolor="none",
    alpha=0.8,
)

print("plotted hexagons")

not_city.plot(
    ax=ax,
    color="white",
    edgecolor="none",
    alpha=0.4,
)
print("plotted city negative")

royan_city.plot(ax=ax, color="none", edgecolor="black", linewidth=0.4, alpha=1)

print("plotted city boundary")

selected_sites_10.plot(
    ax=ax,
    color="red",
    edgecolor="none",
)

print("plotted selected sites for 10 spots")

selected_sites_20.plot(
    ax=ax,
    color="#e58213",
    edgecolor="none",
)

print("plotted selected sites for 20 spots")


# LEGEND
## legend elements

hexagon1 = Line2D(
    [0], [0], color="red", marker="h", linewidth=0, markersize=11, alpha=0.8
)
hexagon2 = Line2D(
    [0], [0], color="#e58213", marker="h", linewidth=0, markersize=11, alpha=0.8
)
line = Line2D([0], [0], color="black", linewidth=0.6, markersize=1, alpha=1)
cmap_gradient = get_gradient_cmap()

## labels
if len(selected_sites_20) > 0 and len(selected_sites_10) > 0:
    if country_code == "FR":
        labels = [
            "Potentiel emplacement station 20 spots",
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = [
            "Bikeshare station 20 spots",
            "Bikeshare station 10 spots",
            "Bikeshare potential",
            "City limit",
        ]
    handles = [hexagon1, hexagon2, cmap_gradient, line]

elif len(selected_sites_20) > 0 and len(selected_sites_10) == 0:
    if country_code == "FR":
        labels = [
            "Potentiel emplacement station 20 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 20 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

else:
    if country_code == "FR":

        labels = [
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 10 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

add_legend(ax, labels, handles, title="Royan VLS", location="upper center")
# add_city_names(city, font_size=7)
add_north_arrow(ax)
add_scalebar(ax)

print("plotted map elements")


# basemap
cx.add_basemap(
    ax,
    crs=city.crs,
    # source =#cx.providers.Esri.WorldGrayCanvas ,#cx.providers.OpenStreetMap.Mapnik,#cx.providers.Stamen.TonerLite, #cx.providers.Stamen.Toner , #cx.providers.Stamen.Terrain
    source=cx.providers.Stamen.Terrain,
    attribution=False,
    attribution_size=7,
)
print("plotted basemap")

# map_color = fig
royan_color = fig

plt.savefig(
    os.path.join(data_dir_out, "Royan_stations.png"),
    dpi=300,
    facecolor="w",
    bbox_inches="tight",
)

print("saved map")
# Out:
# plotted hexagons
# plotted city negative
# plotted city boundary
# plotted selected sites for 10 spots
# plotted selected sites for 20 spots
# plotted map elements
# plotted basemap
# saved map

# %%
add_Quicksand_font()

not_city = get_city_negative(royan_city)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
_ = ax.axis("off")

# reset zoom level (due to not_city box)
xlim, ylim = get_map_limits(royan_city)

# xlim = [823630.250588381, 838316.024679207]
# ylim = [6279944.366917977, 6294579.44074818]

ax.set_xlim(xlim)
ax.set_ylim(ylim)

geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data.query("score > score.quantile(.8)").plot(
    ax=ax,
    column="score",
    scheme="fisher_jenks_sampled",
    k=7,
    cmap="Blues",
    edgecolor="none",
    alpha=0.8,
)

print("plotted hexagons")

not_city.plot(
    ax=ax,
    color="white",
    edgecolor="none",
    alpha=0.4,
)
print("plotted city negative")

royan_city.plot(ax=ax, color="none", edgecolor="black", linewidth=0.4, alpha=1)

print("plotted city boundary")

selected_sites_20.plot(
    ax=ax,
    color="red",
    edgecolor="none",
)

print("plotted selected sites for 10 spots")

selected_sites_10.plot(
    ax=ax,
    color="#e58213",
    edgecolor="none",
)

print("plotted selected sites for 20 spots")


# LEGEND
## legend elements

hexagon1 = Line2D(
    [0], [0], color="red", marker="h", linewidth=0, markersize=11, alpha=0.8
)
hexagon2 = Line2D(
    [0], [0], color="#e58213", marker="h", linewidth=0, markersize=11, alpha=0.8
)
line = Line2D([0], [0], color="black", linewidth=0.6, markersize=1, alpha=1)
cmap_gradient = get_gradient_cmap()

## labels
if len(selected_sites_20) > 0 and len(selected_sites_10) > 0:
    if country_code == "FR":
        labels = [
            "Station de la gare (20 places)",
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = [
            "Bikeshare station 20 spots",
            "Bikeshare station 10 spots",
            "Bikeshare potential",
            "City limit",
        ]
    handles = [hexagon1, hexagon2, cmap_gradient, line]

elif len(selected_sites_20) > 0 and len(selected_sites_10) == 0:
    if country_code == "FR":
        labels = [
            "Potentiel emplacement station 20 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 20 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

else:
    if country_code == "FR":

        labels = [
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 10 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

add_legend(ax, labels, handles, title="Royan VLS", location="upper center")
# add_city_names(city, font_size=7)
add_north_arrow(ax)
add_scalebar(ax)

print("plotted map elements")


# basemap
cx.add_basemap(
    ax,
    crs=city.crs,
    # source =#cx.providers.Esri.WorldGrayCanvas ,#cx.providers.OpenStreetMap.Mapnik,#cx.providers.Stamen.TonerLite, #cx.providers.Stamen.Toner , #cx.providers.Stamen.Terrain
    source=cx.providers.Esri.WorldGrayCanvas,
    attribution=False,
    attribution_size=7,
)
print("plotted basemap")

# map_color = fig
map_royan = fig

plt.savefig(
    os.path.join(data_dir_out, "Royan_stations.png"),
    dpi=300,
    facecolor="w",
    bbox_inches="tight",
)

print("saved map")
# Out:
# plotted hexagons
# plotted city negative
# plotted city boundary
# plotted selected sites for 10 spots
# plotted selected sites for 20 spots
# plotted map elements
# plotted basemap
# saved map

# %%
add_Quicksand_font()

not_city = get_city_negative(cognac_city)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
_ = ax.axis("off")

# reset zoom level (due to not_city box)
xlim, ylim = get_map_limits(cognac_city)

# xlim = [823630.250588381, 838316.024679207]
# ylim = [6279944.366917977, 6294579.44074818]

ax.set_xlim(xlim)
ax.set_ylim(ylim)

geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data.query("score > score.quantile(.8)").plot(
    ax=ax,
    column="score",
    scheme="fisher_jenks_sampled",
    k=7,
    cmap="Blues",
    edgecolor="none",
    alpha=0.8,
)

print("plotted hexagons")

not_city.plot(
    ax=ax,
    color="white",
    edgecolor="none",
    alpha=0.4,
)
print("plotted city negative")

cognac_city.plot(ax=ax, color="none", edgecolor="black", linewidth=0.4, alpha=1)

print("plotted city boundary")

selected_sites_20.plot(
    ax=ax,
    color="red",
    edgecolor="none",
)

print("plotted selected sites for 10 spots")

selected_sites_10.plot(
    ax=ax,
    color="#e58213",
    edgecolor="none",
)

print("plotted selected sites for 20 spots")


# LEGEND
## legend elements

hexagon1 = Line2D(
    [0], [0], color="red", marker="h", linewidth=0, markersize=11, alpha=0.8
)
hexagon2 = Line2D(
    [0], [0], color="#e58213", marker="h", linewidth=0, markersize=11, alpha=0.8
)
line = Line2D([0], [0], color="black", linewidth=0.6, markersize=1, alpha=1)
cmap_gradient = get_gradient_cmap()

## labels
if len(selected_sites_20) > 0 and len(selected_sites_10) > 0:
    if country_code == "FR":
        labels = [
            "Station de la gare (20 places)",
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = [
            "Bikeshare station 20 spots",
            "Bikeshare station 10 spots",
            "Bikeshare potential",
            "City limit",
        ]
    handles = [hexagon1, hexagon2, cmap_gradient, line]

elif len(selected_sites_20) > 0 and len(selected_sites_10) == 0:
    if country_code == "FR":
        labels = [
            "Potentiel emplacement station 20 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 20 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

else:
    if country_code == "FR":

        labels = [
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 10 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

add_legend(ax, labels, handles, title="Cognac VLS", location="upper center")
# add_city_names(city, font_size=7)
add_north_arrow(ax)
add_scalebar(ax)

print("plotted map elements")


# basemap
cx.add_basemap(
    ax,
    crs=city.crs,
    # source =#cx.providers.Esri.WorldGrayCanvas ,#cx.providers.OpenStreetMap.Mapnik,#cx.providers.Stamen.TonerLite, #cx.providers.Stamen.Toner , #cx.providers.Stamen.Terrain
    source=cx.providers.Esri.WorldGrayCanvas,
    attribution=False,
    attribution_size=7,
)
print("plotted basemap")

# map_color = fig
map_cognac = fig

plt.savefig(
    os.path.join(data_dir_out, "Cognac_stations.png"),
    dpi=300,
    facecolor="w",
    bbox_inches="tight",
)

print("saved map")
# Out:
# plotted hexagons
# plotted city negative
# plotted city boundary
# plotted selected sites for 10 spots
# plotted selected sites for 20 spots
# plotted map elements
# plotted basemap
# saved map

# %%
add_Quicksand_font()

not_city = get_city_negative(angouleme_city)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
_ = ax.axis("off")

# reset zoom level (due to not_city box)
xlim, ylim = get_map_limits(angouleme_city)

# xlim = [823630.250588381, 838316.024679207]
# ylim = [6279944.366917977, 6294579.44074818]

ax.set_xlim(xlim)
ax.set_ylim(ylim)

geo_data_dict["FINAL_SCORE_ALL_PER_HEX"].data.query("score > score.quantile(.8)").plot(
    ax=ax,
    column="score",
    scheme="fisher_jenks_sampled",
    k=7,
    cmap="Blues",
    edgecolor="none",
    alpha=0.8,
)

print("plotted hexagons")

not_city.plot(
    ax=ax,
    color="white",
    edgecolor="none",
    alpha=0.4,
)
print("plotted city negative")

angouleme_city.plot(ax=ax, color="none", edgecolor="black", linewidth=0.4, alpha=1)

print("plotted city boundary")

selected_sites_20.plot(
    ax=ax,
    color="red",
    edgecolor="none",
)

print("plotted selected sites for 10 spots")

selected_sites_10.plot(
    ax=ax,
    color="#e58213",
    edgecolor="none",
)

print("plotted selected sites for 20 spots")


# LEGEND
## legend elements

hexagon1 = Line2D(
    [0], [0], color="red", marker="h", linewidth=0, markersize=11, alpha=0.8
)
hexagon2 = Line2D(
    [0], [0], color="#e58213", marker="h", linewidth=0, markersize=11, alpha=0.8
)
line = Line2D([0], [0], color="black", linewidth=0.6, markersize=1, alpha=1)
cmap_gradient = get_gradient_cmap()

## labels
if len(selected_sites_20) > 0 and len(selected_sites_10) > 0:
    if country_code == "FR":
        labels = [
            "Station de la gare (20 places)",
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = [
            "Bikeshare station 20 spots",
            "Bikeshare station 10 spots",
            "Bikeshare potential",
            "City limit",
        ]
    handles = [hexagon1, hexagon2, cmap_gradient, line]

elif len(selected_sites_20) > 0 and len(selected_sites_10) == 0:
    if country_code == "FR":
        labels = [
            "Potentiel emplacement station 20 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 20 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

else:
    if country_code == "FR":

        labels = [
            "Potentiel emplacement station 10 spots",
            "Score de demande latente",
            "Limite commune",
        ]
    else:
        labels = ["Bikeshare station 10 spots", "Bikeshare potential", "City limit"]
    handles = [hexagon1, cmap_gradient, line]

add_legend(ax, labels, handles, title="Angoulême VLS", location="upper center")
# add_city_names(city, font_size=7)
add_north_arrow(ax)
add_scalebar(ax)

print("plotted map elements")


# basemap
cx.add_basemap(
    ax,
    crs=city.crs,
    # source =#cx.providers.Esri.WorldGrayCanvas ,#cx.providers.OpenStreetMap.Mapnik,#cx.providers.Stamen.TonerLite, #cx.providers.Stamen.Toner , #cx.providers.Stamen.Terrain
    source=cx.providers.Esri.WorldGrayCanvas,
    attribution=False,
    attribution_size=7,
)
print("plotted basemap")

# map_color = fig
map_angouleme = fig

plt.savefig(
    os.path.join(data_dir_out, "Angouleme_stations.png"),
    dpi=300,
    facecolor="w",
    bbox_inches="tight",
)

print("saved map")
# Out:
# plotted hexagons
# plotted city negative
# plotted city boundary
# plotted selected sites for 10 spots
# plotted selected sites for 20 spots
# plotted map elements
# plotted basemap
# saved map

# %%
selected_sites_no_k_ring = selected_sites.copy()
selected_sites_no_k_ring.drop(columns="k_ring_3", inplace=True)
m = selected_sites_no_k_ring.explore(
    "site_rank",
    height="100%",
    width="100%",
)
city.explore(m=m, style_kwds={"fill": False})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5a1b9041b6adc852ca318e2d011ff59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5a1b9041b6adc852ca318e2d011ff59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a5a1b9041b6adc852ca318e2d011ff59 = L.map(
#                 &quot;map_a5a1b9041b6adc852ca318e2d011ff59&quot;,
#                 {
#                     center: [45.65989469124362, -0.4381410928956934],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a5a1b9041b6adc852ca318e2d011ff59);
#
#
#
#
#
#             var tile_layer_6490638f7b27b932640203de86e907ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a5a1b9041b6adc852ca318e2d011ff59);
#
#
#             map_a5a1b9041b6adc852ca318e2d011ff59.fitBounds(
#                 [[45.619399759866575, -1.0510631843143967], [45.700389622620676, 0.17478099852300988]],
#                 {}
#             );
#
#
#         function geo_json_1f469dd16f52f2e1d6429daf6aeece5d_styler(feature) {
#             switch(feature.properties.hex10) {
#                 case &quot;8a186b80655ffff&quot;: case &quot;8a186a2d8617fff&quot;: case &quot;8a186bc01287fff&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b80605ffff&quot;: case &quot;8a186a2d8457fff&quot;: case &quot;8a186bc0c437fff&quot;:
#                     return {&quot;color&quot;: &quot;#482878&quot;, &quot;fillColor&quot;: &quot;#482878&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b810b17fff&quot;: case &quot;8a186a2d8777fff&quot;: case &quot;8a186bc0e977fff&quot;:
#                     return {&quot;color&quot;: &quot;#3e4989&quot;, &quot;fillColor&quot;: &quot;#3e4989&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b802457fff&quot;: case &quot;8a186a2da02ffff&quot;: case &quot;8a186bc0cd4ffff&quot;:
#                     return {&quot;color&quot;: &quot;#31688e&quot;, &quot;fillColor&quot;: &quot;#31688e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b81599ffff&quot;: case &quot;8a186a2dbd07fff&quot;: case &quot;8a186bc0c1b7fff&quot;:
#                     return {&quot;color&quot;: &quot;#26828e&quot;, &quot;fillColor&quot;: &quot;#26828e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b80671ffff&quot;: case &quot;8a186a2d8cd7fff&quot;: case &quot;8a186bc0eab7fff&quot;:
#                     return {&quot;color&quot;: &quot;#1f9e89&quot;, &quot;fillColor&quot;: &quot;#1f9e89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b802087fff&quot;: case &quot;8a186a2d8a9ffff&quot;: case &quot;8a186bc0c6b7fff&quot;:
#                     return {&quot;color&quot;: &quot;#35b779&quot;, &quot;fillColor&quot;: &quot;#35b779&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b8154cffff&quot;:
#                     return {&quot;color&quot;: &quot;#b5de2b&quot;, &quot;fillColor&quot;: &quot;#b5de2b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8a186b81502ffff&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#6ece58&quot;, &quot;fillColor&quot;: &quot;#6ece58&quot;, &quot;fillOpacity&quot;: 0.5, &quot

# %%
display(Markdown(f"## Exports"))
# Out:
# ## Exports

# %%
city_boundary = city.copy()  # .query("city_name.isin(@curr_city)").copy()
city_boundary.geometry = city_boundary.boundary

# %%
temp_dict = {
    "city": city_boundary,
    "stations": selected_sites[
        [
            "geometry",
            "city_name",
        ]
    ],
}
temp_dict_20 = {
    "stations_10": selected_sites_10[
        [
            "geometry",
            "bike_spots",
            "city_name",
        ]
    ],
}
temp_dict_10 = {
    "stations_20": selected_sites_20[
        [
            "geometry",
            "bike_spots",
            "city_name",
        ]
    ],
}

# %%
save_gdf(temp_dict, data_dir_out, place)
# Out:
# /home/vincentaguerrechariol/Documents/repos/data-notebook-sharing/urban_analytics/data/out/FR/Royan-Cognac-Angoulème/Royan-Cognac-Angoulème_city.kml created
# /home/vincentaguerrechariol/Documents/repos/data-notebook-sharing/urban_analytics/data/out/FR/Royan-Cognac-Angoulème/Royan-Cognac-Angoulème_stations.kml created

# %%
save_gdf(temp_dict_20, data_dir_out, place)
save_gdf(temp_dict_10, data_dir_out, place)
# Out:
# /home/vincentaguerrechariol/Documents/repos/data-notebook-sharing/urban_analytics/data/out/FR/Royan-Cognac-Angoulème/Royan-Cognac-Angoulème_stations_10.kml created
# /home/vincentaguerrechariol/Documents/repos/data-notebook-sharing/urban_analytics/data/out/FR/Royan-Cognac-Angoulème/Royan-Cognac-Angoulème_stations_20.kml created

# %%
display(Markdown(f"## Deliverables"))
# Out:
# ## Deliverables

# %%
MAINTENANCE_BUFFER = 0.1

# %%
# | output: true
if country_code == "FR":
    display(Markdown("### Dimensionnement de la flotte\n\n"))
else:
    display(Markdown("### Fleet Sizing\n\n"))
# Out:
# ### Dimensionnement de la flotte

# %%
# | output: true

print_vls_table(market_vls, country_code)
# Out:
#            Population  Vélos  Stations
# Communes
# Angoulême       41603     60        10
# Royan           18419     50         8
# Cognac          18670     50         8
# Total           78692    160        26

# %%
# | output: true
buffer_bikes = my_round(market_vls.rounded_bikes.sum() * MAINTENANCE_BUFFER, 10)

if country_code == "FR":
    display(
        Markdown(
            "__Taille de la flotte de vélos:__\n\n"
            f"- {market_vls.rounded_bikes.sum() + buffer_bikes} vélos totaux en libre service ({market_vls.rounded_bikes.sum()} vélos + {buffer_bikes} dédiés à la maintenance)\n"
            # f"- {market_vld['bikes'].sum()} vélos en location longue durée \n"
            f"- {market_vls.stations.sum()} stations\n\n"
            # f"  - {len(selected_sites_20)} stations à 20 emplacements\n"
            # f"  - {len(selected_sites_10)} stations à 10 emplacements"
        )
    )

else:
    display(
        Markdown(
            "__Overall bike share fleet:__\n\n"
            f"- {market_vls.rounded_bikes.sum() + buffer_bikes} total bikes for bike sharing ({market_vls.rounded_bikes.sum()} bikes + {buffer_bikes} maintenance buffer)\n"
            f"- {market_vld['bikes'].sum()} bikes for long term renting \n"
            f"- {market_vls.stations.sum()} stations\n\n"
            # f"  - {len(selected_sites_20)} stations w/ 20 spots\n"
            f"  - {len(selected_sites_10)} stations w/ 10 spots"
        )
    )
# Out:
# __Taille de la flotte de vélos:__
#
# - 180 vélos totaux en libre service (160 vélos + 20 dédiés à la maintenance)
# - 26 stations

# %%
# | output: true
if country_code == "FR":
    display(Markdown("### Réseau de stations\n\n"))
else:
    display(Markdown("### Bikeshare network\n\n"))
# Out:
# ### Réseau de stations

# %% [raw]
# ::: {.panel-tabset}
#
# ###  Royan

# %%
# | output: true
map_royan

# %% [raw]
# ###  Cognac

# %%
# | output: true
map_cognac

# %% [raw]
# ###  Angoulême

# %%
# | output: true
map_angouleme

# %% [raw]
# :::

# %%
# Google my maps legends
if country_code == "FR":
    output = (
        f"{place} - Proposition Réseau VLS\n\n"
        "Emplacement approx. stations VLS\n\n"
        "Limites communes\n\n"
    )
else:
    output = (
        f"{place} - Bike Share Network Proposal\n\n"
        "Approx. bike station location\n\n"
        "City boundary"
    )

Markdown(output)
# Out:
# Royan-Cognac-Angoulème - Proposition Réseau VLS
#
# Emplacement approx. stations VLS
#
# Limites communes

# %%
# | output: true
display(
    Markdown(
        "Google My Maps [link](https://www.google.com/maps/d/edit?mid=1j6kSouY1xArUNi9mIZ_VyHwWbX0N5Ms&usp=sharing)\n\n"
    )
)
# Out:
# Google My Maps [link](https://www.google.com/maps/d/edit?mid=1j6kSouY1xArUNi9mIZ_VyHwWbX0N5Ms&usp=sharing)

# %%
# | output: true
if country_code == "FR":
    with pd.option_context("float_format", "{:.2f}".format):
        display(
            Markdown(
                "__Distance entre les stations__ \n\n"
                f"Interdistance moyenne : {round(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).mean())} mètres\n\n"
                f"Distance minimale : {(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).min()).astype(int)} mètres\n\n"
                f"Distance maximale : {(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).max()).astype(int)} mètres\n\n"
            )
        )
else:
    with pd.option_context("float_format", "{:.2f}".format):
        display(
            Markdown(
                "__Distance between stations__ \n\n"
                f"Average distance : {round(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).mean())} meters\n\n"
                f"Minimum distance : {(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).min()).astype(int)} meters\n\n"
                f"Maximum distance : {(weighted_dist_to_next_site(selected_sites, weights=[1, 0]).max()).astype(int)} meters\n\n"
            )
        )
# Out:
# __Distance entre les stations__
#
# Interdistance moyenne : 520 mètres
#
# Distance minimale : 360 mètres
#
# Distance maximale : 829 mètres

# %%
# | output: true

if country_code == "FR":
    display(Markdown("__Approximation de la couverture de population__\n\n"))
else:
    display(Markdown("__Approximate population coverage__\n\n"))

for buffer in [400, 1000]:

    covered_pop = get_pop_coverage(
        selected_sites,
        geo_data_dict["POPULATION_ALL_PER_POINT"].data,
        local_crs,
        buffer=buffer,
    )
    if country_code == "FR":
        display(
            Markdown(
                f"Population à moins de {buffer}m d'une station : {covered_pop} soit environ {round(covered_pop/total_pop*100)}% de la population"
            )
        )
    else:
        display(
            Markdown(
                f"People living less than {buffer}m from a station : {covered_pop} being around {round(covered_pop/total_pop*100)}% of total population"
            )
        )
# Out:
# __Approximation de la couverture de population__
# Population à moins de 400m d'une station : 45541 soit environ 61% de la population
# Population à moins de 1000m d'une station : 69835 soit environ 93% de la population

# %%
# | output: true
if country_code == "FR":
    display(Markdown("### Prédictions d'indicateurs de performance\n\n\n"))
else:
    display(Markdown("### Performance prediction indicators\n\n\n"))
# Out:
# ### Prédictions d'indicateurs de performance

# %%
predictive_db = get_base_predictions_db(market_vls)
royan_pred_db = get_kpi_db_market(predictive_db[predictive_db["LIBGEO"] == "Royan"], 50)
cognac_pred_db = get_kpi_db_market(
    predictive_db[predictive_db["LIBGEO"] == "Cognac"], 50
)
angouleme_pred_db = get_kpi_db_market(
    predictive_db[predictive_db["LIBGEO"] == "Angoulême"], 60
)
kpi_db = pd.concat([royan_pred_db, cognac_pred_db, angouleme_pred_db])
kpi_db = get_bike_rotation(kpi_db)
kpi_db = get_maintenance_costs(kpi_db)
kpi_db.reset_index(inplace=True, drop=True)
kpi_db
# Out:
#       LIBGEO  CODGEO                LIBEPCI  population  surplus_workers DEP  \
# 0      Royan    5840    CA Royan Atlantique       18419             3018  17
# 1     Cognac    5274     CA du Grand Cognac       18670             3100  16
# 2  Angoulême    5196  CA du Grand Angoulême       41603             8335  16
#
#    proposed_bikes  base_bikes  rounded_bikes  final_pop_coeff  ...  \
# 0              50     62.3812             50         0.708675  ...
# 1              50     60.9560             50         1.075855  ...
# 2              60    123.0082             60         1.241508  ...
#
#    P_high_day_rotation  O_low_day_rotation  O_med_day_rotation  \
# 0                 0.81                3.30                1.81
# 1                 0.82                3.57                1.87
# 2                 1.03                4.59                2.38
#
#    O_high_day_rotation  P_low_cost_Y  P_med_cost_Y  P_high_cost_Y  \
# 0                 1.35         11241          7820           6754
# 1                 1.40          9841          6522           5592
# 2                 1.78         14146          8983           7577
#
#    O_low_cost_Y  O_med_cost_Y  O_high_cost_Y
# 0         16561         10679           8898
# 1         14982          9187           7591
# 2         22118         13077          10648
#
# [3 rows x 48 columns]

# %%
# | output: true

print_predictions_header(
    kpi_db,
    country_code,
)
# Out:
# __Scénarios pessimistes et optimistes pour Royan avec une proposition de 160 vélos__
#
# Utilisateurs attendus par an: 3,874 à 6,853

# %% [raw]
# ::: {.panel-tabset}
#
# ###  Prix bas

# %%
# | output: true
print_kpi_predictions_panel(kpi_db, country_code, ["low"])
# Out:
#  Estimation de politique de prix bas
#
# - Trajets attendus par an: 130,967 (19,868 liés au tourisme) à 225,769 (29,216 liés au tourisme)
# - Rotation journalière par vélo attendue: 2.24 à 3.87
# - Kilomètres attendus par an: 458,386 à 790,193
# - Couts de maintenance attendus par an: 35,228€ à 53,661€
# - Kilos de CO2 évités attendus par an: 27,962 à 48,202

# %% [raw]
# ###  Prix moyen

# %%
# | output: true
print_kpi_predictions_panel(kpi_db, country_code, ["med"])
# Out:
#  Estimation de politique de prix moyen
#
# - Trajets attendus par an: 69,741 (14,192 liés au tourisme) à 119,146 (20,869 liés au tourisme)
# - Rotation journalière par vélo attendue: 1.19 à 2.04
# - Kilomètres attendus par an: 244,094 à 417,010
# - Couts de maintenance attendus par an: 23,325€ à 32,943€
# - Kilos de CO2 évités attendus par an: 14,889 à 25,437

# %% [raw]
# ###  Prix haut

# %%
# | output: true
print_kpi_predictions_panel(kpi_db, country_code, ["high"])
# Out:
#  Estimation de politique de prix élevé
#
# - Trajets attendus par an: 52,306 (10,644 liés au tourisme) à 89,361 (15,651 liés au tourisme)
# - Rotation journalière par vélo attendue: 0.9 à 1.53
# - Kilomètres attendus par an: 183,068 à 312,761
# - Couts de maintenance attendus par an: 19,923€ à 27,137€
# - Kilos de CO2 évités attendus par an: 11,167 à 19,078

# %% [raw]
# :::

# %%
# | output: true
if country_code == "FR":
    display(
        Markdown("### Tableau de bord des prédictions d'indicateurs de performance\n\n")
    )
else:
    display(Markdown("### KPIs prediction dashboard\n\n"))
# Out:
# ### Tableau de bord des prédictions d'indicateurs de performance

# %%
# | output: true
# | column: screen

get_plotly_KPIs(kpi_db, country_code, dashboard_height_margin=500)

# %%
# app = JupyterDash(__name__)
# app.layout = html.Div(
#     children=[
#         dcc.Graph(
#             id="kpi_dashboard",
#             figure=get_plotly_KPIs(kpi_db),
#         ),
#         dcc.Checklist(
#             id="town_checklist",
#             options=kpi_db["LIBGEO"],
#             value=kpi_db["LIBGEO"],
#         ),
#     ],
#     style={"height": "90%", "width": "40%"},
# )


# @app.callback(Output("kpi_dashboard", "figure"), Input("town_checklist", "value"))
# def update_fig(outvalues):
#     kpi_db_filtered = kpi_db.query("LIBGEO in @outvalues")
#     fig = get_plotly_KPIs(kpi_db_filtered)

#     return fig

# app.run_server(mode="inline", debug=True, port=8072)
